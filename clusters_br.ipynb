# %%
# Initial imports
import pandas as pd
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
file_path = "merged_data.csv"
merged_df = pd.read_csv(file_path, index_col=0)
merged_df.head(10)
# Out:
#              country_name  year  co2_emissions  merge_id  \
# country_code
# ARM               Armenia  1990      19850.000  ARM_1990
# ARM               Armenia  1991      20690.000  ARM_1991
# ARM               Armenia  1992      10900.000  ARM_1992
# ARM               Armenia  1993       5040.000  ARM_1993
# ARM               Armenia  1994       2740.000  ARM_1994
# ARM               Armenia  1995       3510.000  ARM_1995
# ARM               Armenia  1996       2580.000  ARM_1996
# ARM               Armenia  1997       3340.000  ARM_1997
# ARM               Armenia  1998       3470.000  ARM_1998
# AUS             Australia  1960      88202.351  AUS_1960
#
#               age-standardized_death_rate_per_100k_male  \
# country_code
# ARM                                               51.36
# ARM                                               49.99
# ARM                                               45.04
# ARM                                               40.77
# ...

# %%
merged_df.isnull().sum()
# Out:
# country_name                                                                        0
# year                                                                                0
# co2_emissions                                                                       0
# merge_id                                                                            0
# age-standardized_death_rate_per_100k_male                                           0
# age-standardized_death_rate_per_100k_female                                         0
# Sales of cigarettes per adult per day (International Smoking Statistics (2017))     0
# dtype: int64

# %%
country_name=pd.DataFrame(merged_df['country_name'])
country_name
# Out:
#                country_name
# country_code
# ARM                 Armenia
# ARM                 Armenia
# ARM                 Armenia
# ARM                 Armenia
# ARM                 Armenia
# ...                     ...
# USA           United States
# USA           United States
# USA           United States
# USA           United States
# USA           United States
#
# [1593 rows x 1 columns]

# %%
merged_df.drop(columns="country_name", inplace=True)
merged_df
# Out:
#               year  co2_emissions  merge_id  \
# country_code
# ARM           1990   1.985000e+04  ARM_1990
# ARM           1991   2.069000e+04  ARM_1991
# ARM           1992   1.090000e+04  ARM_1992
# ARM           1993   5.040000e+03  ARM_1993
# ARM           1994   2.740000e+03  ARM_1994
# ...            ...            ...       ...
# USA           2010   5.392110e+06  USA_2010
# USA           2011   5.173600e+06  USA_2011
# USA           2012   4.956060e+06  USA_2012
# USA           2013   5.092100e+06  USA_2013
# USA           2014   5.107210e+06  USA_2014
#
#               age-standardized_death_rate_per_100k_male  \
# country_code
# ARM                                               51.36
# ARM                                               49.99
# ARM                                               45.04
# ARM                                               40.77
# ARM                                               36.68
# ...                                                 ...
# ...

# %%
merged_df.drop(columns="merge_id", inplace=True)
merged_df
# Out:
#               year  co2_emissions  age-standardized_death_rate_per_100k_male  \
# country_code
# ARM           1990   1.985000e+04                                      51.36
# ARM           1991   2.069000e+04                                      49.99
# ARM           1992   1.090000e+04                                      45.04
# ARM           1993   5.040000e+03                                      40.77
# ARM           1994   2.740000e+03                                      36.68
# ...            ...            ...                                        ...
# USA           2010   5.392110e+06                                      40.85
# USA           2011   5.173600e+06                                      39.27
# USA           2012   4.956060e+06                                      38.15
# USA           2013   5.092100e+06                                      36.62
# USA           2014   5.107210e+06                                      35.31
#
# ...

# %%
merged_df.dtypes
# Out:
# year                                                                                  int64
# co2_emissions                                                                       float64
# age-standardized_death_rate_per_100k_male                                           float64
# age-standardized_death_rate_per_100k_female                                         float64
# Sales of cigarettes per adult per day (International Smoking Statistics (2017))     float64
# dtype: object

# %%
# x = pd.get_dummies(merged_df, columns=['', ''])
# x

# %%
# x_scaled =  StandardScaler().fit_transform(x)
# x_scaled
