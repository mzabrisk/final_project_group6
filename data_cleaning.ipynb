# %%
import pandas as pd

# %%
co2_data = 'Resources/co2_emissions_kt_by_country.csv'
co2_df = pd.read_csv(co2_data)
print(co2_df.shape)
co2_df.head()
# Out:
# (13953, 4)
#   country_code country_name  year      value
# 0          ABW        Aruba  1960  11092.675
# 1          ABW        Aruba  1961  11576.719
# 2          ABW        Aruba  1962  12713.489
# 3          ABW        Aruba  1963  12178.107
# 4          ABW        Aruba  1964  11840.743

# %%
print(len(co2_df['country_code'].value_counts()))
print(co2_df['country_code'].value_counts())
# Out:
# 255
# LBY    60
# STP    60
# LAO    60
# LBN    60
# LBR    60
#        ..
# TCA    27
# PSE    27
# XKX     9
# CUW     5
# SXM     3
# Name: country_code, Length: 255, dtype: int64

# %%
# creating new index for co2_df to enable merging dfs
co2_index = []

for i, row in co2_df.iterrows():
    value = f"{co2_df['country_code'][i]}_{co2_df['year'][i]}"
    co2_index.append(value)

co2_index
# Out:
# ['ABW_1960',
#  'ABW_1961',
#  'ABW_1962',
#  'ABW_1963',
#  'ABW_1964',
#  'ABW_1965',
#  'ABW_1966',
#  'ABW_1967',
#  'ABW_1968',
#  'ABW_1969',
#  'ABW_1970',
#  'ABW_1971',
#  'ABW_1972',
#  'ABW_1973',
#  'ABW_1974',
#  'ABW_1975',
#  'ABW_1976',
#  'ABW_1977',
#  'ABW_1978',
#  'ABW_1979',
#  'ABW_1980',
#  'ABW_1981',
#  'ABW_1982',
#  'ABW_1983',
#  'ABW_1984',
#  'ABW_1985',
#  'ABW_1986',
#  'ABW_1987',
#  'ABW_1988',
#  'ABW_1989',
#  'ABW_1990',
#  'ABW_1991',
#  'ABW_1992',
#  'ABW_1993',
#  'ABW_1994',
#  'ABW_1995',
#  'ABW_1996',
#  'ABW_1997',
#  'ABW_1998',
#  'ABW_1999',
#  'ABW_2000',
#  'ABW_2001',
#  'ABW_2002',
#  'ABW_2003',
#  'ABW_2004',
#  'ABW_2005',
#  'ABW_2006',
#  'ABW_2007',
#  'ABW_2008',
#  'ABW_2009',
#  'ABW_2010',
#  'ABW_2011',
#  'ABW_2012',
#  'ABW_2013',
#  'ABW_2014',
#  'ABW_2015',
#  'ABW_2016',
#  'AFE_1960',
#  'AFE_1961',
#  'AFE_1962',
#  'AFE_1963',
#  'AFE_1964',
#  'AFE_1965',
#  'AFE_1966',
#  'AFE_1967',
#  'AFE_1968',
#  'AFE_1969',
#  'AFE_1970',
#  'AFE_1971',
#  'AFE_1972',
#  'AFE_1973',
#  'AFE_1974',
#  'AFE_1975',
#  'AFE_1976',
#  'AFE_1977',
#  'AFE_1978',
#  'AFE_1979',
#  'AFE_1980',
#  'AFE_1981',
#  'AFE_1982',
#  'AFE_1983',
#  'AFE_1984',
#  'AFE_1985',
#  'AFE_1986',
#  'AFE_1987',
#  'AFE_1988',
#  'AFE_1989',
#  'AFE_1990',
#  'AFE_1991',
#  'AFE_1992',
#  'AFE_1993',
#  'AFE_1994',
#  'AFE_1995',
#  'AFE_1996',
#  'AFE_1997',
#  'AFE_1998',
#  'AFE_1999',
#  'AFE_2000',
#  'AFE_2001',
#  'AFE_2002',
#  'AFE_2003',
#  'AFE_2004',
#  'AFE_2005',
#  'AFE_2006',
#  'AFE_2007',
#  'AFE_2008',
#  'AFE_2009',
#  'AFE_2010',
#  'AFE_2011',
#  'AFE_2012',
#  'AFE_2013',
#  'AFE_2014',
#  'AFE_2015',
#  'AFE_2016',
#  'AFE_2017',
#  'AFE_2018',
#  'AFE_2019',
#  'AFG_1960',
#  'AFG_1961',
#  'AFG_1962',
#  'AFG_1963',
#  'AFG_1964',
#  'AFG_1965',
#  'AFG_1966',
#  'AFG_1967',
#  'AFG_1968',
#  'AFG_1969',
#  'AFG_1970',
#  'AFG_1971',
#  'AFG_1972',
#  'AFG_1973',
#  'AFG_1974',
#  'AFG_1975',
#  'AFG_1976',
#  'AFG_1977',
#  'AFG_1978',
#  'AFG_1979',
#  'AFG_1980',
#  'AFG_1981',
#  'AFG_1982',
#  'AFG_1983',
#  'AFG_1984',
#  'AFG_1985',
#  'AFG_1986',
#  'AFG_1987',
#  'AFG_1988',
#  'AFG_1989',
#  'AFG_1990',
#  'AFG_1991',
#  'AFG_1992',
#  'AFG_1993',
#  'AFG_1994',
#  'AFG_1995',
#  'AFG_1996',
#  'AFG_1997',
#  'AFG_1998',
#  'AFG_1999',
#  'AFG_2000',
#  'AFG_2001',
#  'AFG_2002',
#  'AFG_2003',
#  'AFG_2004',
#  'AFG_2005',
#  'AFG_2006',
#  'AFG_2007',
#  'AFG_2008',
#  'AFG_2009',
#  'AFG_2010',
#  'AFG_2011',
#  'AFG_2012',
#  'AFG_2013',
#  'AFG_2014',
#  'AFG_2015',
#  'AFG_2016',
#  'AFG_2017',
#  'AFG_2018',
#  'AFG_2019',
#  'AFW_1960',
#  'AFW_1961',
#  'AFW_1962',
#  'AFW_1963',
#  'AFW_1964',
#  'AFW_1965',
#  'AFW_1966',
#  'AFW_1967',
#  'AFW_1968',
#  'AFW_1969',
#  'AFW_1970',
#  'AFW_1971',
#  'AFW_1972',
#  'AFW_1973',
#  'AFW_1974',
#  'AFW_1975',
#  'AFW_1976',
#  'AFW_1977',
#  'AFW_1978',
#  'AFW_1979',
#  'AFW_1980',
#  'AFW_1981',
#  'AFW_1982',
#  'AFW_1983',
#  'AFW_1984',
#  'AFW_1985',
#  'AFW_1986',
#  'AFW_1987',
#  'AFW_1988',
#  'AFW_1989',
#  'AFW_1990',
#  'AFW_1991',
#  'AFW_1992',
#  'AFW_1993',
#  'AFW_1994',
#  'AFW_1995',
#  'AFW_1996',
#  'AFW_1997',
#  'AFW_1998',
#  'AFW_1999',
#  'AFW_2000',
#  'AFW_2001',
#  'AFW_2002',
#  'AFW_2003',
#  'AFW_2004',
#  'AFW_2005',
#  'AFW_2006',
#  'AFW_2007',
#  'AFW_2008',
#  'AFW_2009',
#  'AFW_2010',
#  'AFW_2011',
#  'AFW_2012',
#  'AFW_2013',
#  'AFW_2014',
#  'AFW_2015',
#  'AFW_2016',
#  'AFW_2017',
#  'AFW_2018',
#  'AFW_2019',
#  'AGO_1960',
#  'AGO_1961',
#  'AGO_1962',
#  'AGO_1963',
#  'AGO_1964',
#  'AGO_1965',
#  'AGO_1966',
#  'AGO_1967',
#  'AGO_1968',
#  'AGO_1969',
#  'AGO_1970',
#  'AGO_1971',
#  'AGO_1972',
#  'AGO_1973',
#  'AGO_1974',
#  'AGO_1975',
#  'AGO_1976',
#  'AGO_1977',
#  'AGO_1978',
#  'AGO_1979',
#  'AGO_1980',
#  'AGO_1981',
#  'AGO_1982',
#  'AGO_1983',
#  'AGO_1984',
#  'AGO_1985',
#  'AGO_1986',
#  'AGO_1987',
#  'AGO_1988',
#  'AGO_1989',
#  'AGO_1990',
#  'AGO_1991',
#  'AGO_1992',
#  'AGO_1993',
#  'AGO_1994',
#  'AGO_1995',
#  'AGO_1996',
#  'AGO_1997',
#  'AGO_1998',
#  'AGO_1999',
#  'AGO_2000',
#  'AGO_2001',
#  'AGO_2002',
#  'AGO_2003',
#  'AGO_2004',
#  'AGO_2005',
#  'AGO_2006',
#  'AGO_2007',
#  'AGO_2008',
#  'AGO_2009',
#  'AGO_2010',
#  'AGO_2011',
#  'AGO_2012',
#  'AGO_2013',
#  'AGO_2014',
#  'AGO_2015',
#  'AGO_2016',
#  'AGO_2017',
#  'AGO_2018',
#  'AGO_2019',
#  'ALB_1960',
#  'ALB_1961',
#  'ALB_1962',
#  'ALB_1963',
#  'ALB_1964',
#  'ALB_1965',
#  'ALB_1966',
#  'ALB_1967',
#  'ALB_1968',
#  'ALB_1969',
#  'ALB_1970',
#  'ALB_1971',
#  'ALB_1972',
#  'ALB_1973',
#  'ALB_1974',
#  'ALB_1975',
#  'ALB_1976',
#  'ALB_1977',
#  'ALB_1978',
#  'ALB_1979',
#  'ALB_1980',
#  'ALB_1981',
#  'ALB_1982',
#  'ALB_1983',
#  'ALB_1984',
#  'ALB_1985',
#  'ALB_1986',
#  'ALB_1987',
#  'ALB_1988',
#  'ALB_1989',
#  'ALB_1990',
#  'ALB_1991',
#  'ALB_1992',
#  'ALB_1993',
#  'ALB_1994',
#  'ALB_1995',
#  'ALB_1996',
#  'ALB_1997',
#  'ALB_1998',
#  'ALB_1999',
#  'ALB_2000',
#  'ALB_2001',
#  'ALB_2002',
#  'ALB_2003',
#  'ALB_2004',
#  'ALB_2005',
#  'ALB_2006',
#  'ALB_2007',
#  'ALB_2008',
#  'ALB_2009',
#  'ALB_2010',
#  'ALB_2011',
#  'ALB_2012',
#  'ALB_2013',
#  'ALB_2014',
#  'ALB_2015',
#  'ALB_2016',
#  'ALB_2017',
#  'ALB_2018',
#  'ALB_2019',
#  'AND_1990',
#  'AND_1991',
#  'AND_1992',
#  'AND_1993',
#  'AND_1994',
#  'AND_1995',
#  'AND_1996',
#  'AND_1997',
#  'AND_1998',
#  'AND_1999',
#  'AND_2000',
#  'AND_2001',
#  'AND_2002',
#  'AND_2003',
#  'AND_2004',
#  'AND_2005',
#  'AND_2006',
#  'AND_2007',
#  'AND_2008',
#  'AND_2009',
#  'AND_2010',
#  'AND_2011',
#  'AND_2012',
#  'AND_2013',
#  'AND_2014',
#  'AND_2015',
#  'AND_2016',
#  'AND_2017',
#  'AND_2018',
#  'AND_2019',
#  'ARB_1960',
#  'ARB_1961',
#  'ARB_1962',
#  'ARB_1963',
#  'ARB_1964',
#  'ARB_1965',
#  'ARB_1966',
#  'ARB_1967',
#  'ARB_1968',
#  'ARB_1969',
#  'ARB_1970',
#  'ARB_1971',
#  'ARB_1972',
#  'ARB_1973',
#  'ARB_1974',
#  'ARB_1975',
#  'ARB_1976',
#  'ARB_1977',
#  'ARB_1978',
#  'ARB_1979',
#  'ARB_1980',
#  'ARB_1981',
#  'ARB_1982',
#  'ARB_1983',
#  'ARB_1984',
#  'ARB_1985',
#  'ARB_1986',
#  'ARB_1987',
#  'ARB_1988',
#  'ARB_1989',
#  'ARB_1990',
#  'ARB_1991',
#  'ARB_1992',
#  'ARB_1993',
#  'ARB_1994',
#  'ARB_1995',
#  'ARB_1996',
#  'ARB_1997',
#  'ARB_1998',
#  'ARB_1999',
#  'ARB_2000',
#  'ARB_2001',
#  'ARB_2002',
#  'ARB_2003',
#  'ARB_2004',
#  'ARB_2005',
#  'ARB_2006',
#  'ARB_2007',
#  'ARB_2008',
#  'ARB_2009',
#  'ARB_2010',
#  'ARB_2011',
#  'ARB_2012',
#  'ARB_2013',
#  'ARB_2014',
#  'ARB_2015',
#  'ARB_2016',
#  'ARB_2017',
#  'ARB_2018',
#  'ARB_2019',
#  'ARE_1960',
#  'ARE_1961',
#  'ARE_1962',
#  'ARE_1963',
#  'ARE_1964',
#  'ARE_1965',
#  'ARE_1966',
#  'ARE_1967',
#  'ARE_1968',
#  'ARE_1969',
#  'ARE_1970',
#  'ARE_1971',
#  'ARE_1972',
#  'ARE_1973',
#  'ARE_1974',
#  'ARE_1975',
#  'ARE_1976',
#  'ARE_1977',
#  'ARE_1978',
#  'ARE_1979',
#  'ARE_1980',
#  'ARE_1981',
#  'ARE_1982',
#  'ARE_1983',
#  'ARE_1984',
#  'ARE_1985',
#  'ARE_1986',
#  'ARE_1987',
#  'ARE_1988',
#  'ARE_1989',
#  'ARE_1990',
#  'ARE_1991',
#  'ARE_1992',
#  'ARE_1993',
#  'ARE_1994',
#  'ARE_1995',
#  'ARE_1996',
#  'ARE_1997',
#  'ARE_1998',
#  'ARE_1999',
#  'ARE_2000',
#  'ARE_2001',
#  'ARE_2002',
#  'ARE_2003',
#  'ARE_2004',
#  'ARE_2005',
#  'ARE_2006',
#  'ARE_2007',
#  'ARE_2008',
#  'ARE_2009',
#  'ARE_2010',
#  'ARE_2011',
#  'ARE_2012',
#  'ARE_2013',
#  'ARE_2014',
#  'ARE_2015',
#  'ARE_2016',
#  'ARE_2017',
#  'ARE_2018',
#  'ARE_2019',
#  'ARG_1960',
#  'ARG_1961',
#  'ARG_1962',
#  'ARG_1963',
#  'ARG_1964',
#  'ARG_1965',
#  'ARG_1966',
#  'ARG_1967',
#  'ARG_1968',
#  'ARG_1969',
#  'ARG_1970',
#  'ARG_1971',
#  'ARG_1972',
#  'ARG_1973',
#  'ARG_1974',
#  'ARG_1975',
#  'ARG_1976',
#  'ARG_1977',
#  'ARG_1978',
#  'ARG_1979',
#  'ARG_1980',
#  'ARG_1981',
#  'ARG_1982',
#  'ARG_1983',
#  'ARG_1984',
#  'ARG_1985',
#  'ARG_1986',
#  'ARG_1987',
#  'ARG_1988',
#  'ARG_1989',
#  'ARG_1990',
#  'ARG_1991',
#  'ARG_1992',
#  'ARG_1993',
#  'ARG_1994',
#  'ARG_1995',
#  'ARG_1996',
#  'ARG_1997',
#  'ARG_1998',
#  'ARG_1999',
#  'ARG_2000',
#  'ARG_2001',
#  'ARG_2002',
#  'ARG_2003',
#  'ARG_2004',
#  'ARG_2005',
#  'ARG_2006',
#  'ARG_2007',
#  'ARG_2008',
#  'ARG_2009',
#  'ARG_2010',
#  'ARG_2011',
#  'ARG_2012',
#  'ARG_2013',
#  'ARG_2014',
#  'ARG_2015',
#  'ARG_2016',
#  'ARG_2017',
#  'ARG_2018',
#  'ARG_2019',
#  'ARM_1990',
#  'ARM_1991',
#  'ARM_1992',
#  'ARM_1993',
#  'ARM_1994',
#  'ARM_1995',
#  'ARM_1996',
#  'ARM_1997',
#  'ARM_1998',
#  'ARM_1999',
#  'ARM_2000',
#  'ARM_2001',
#  'ARM_2002',
#  'ARM_2003',
#  'ARM_2004',
#  'ARM_2005',
#  'ARM_2006',
#  'ARM_2007',
#  'ARM_2008',
#  'ARM_2009',
#  'ARM_2010',
#  'ARM_2011',
#  'ARM_2012',
#  'ARM_2013',
#  'ARM_2014',
#  'ARM_2015',
#  'ARM_2016',
#  'ARM_2017',
#  'ARM_2018',
#  'ARM_2019',
#  'ATG_1960',
#  'ATG_1961',
#  'ATG_1962',
#  'ATG_1963',
#  'ATG_1964',
#  'ATG_1965',
#  'ATG_1966',
#  'ATG_1967',
#  'ATG_1968',
#  'ATG_1969',
#  'ATG_1970',
#  'ATG_1971',
#  'ATG_1972',
#  'ATG_1973',
#  'ATG_1974',
#  'ATG_1975',
#  'ATG_1976',
#  'ATG_1977',
#  'ATG_1978',
#  'ATG_1979',
#  'ATG_1980',
#  'ATG_1981',
#  'ATG_1982',
#  'ATG_1983',
#  'ATG_1984',
#  'ATG_1985',
#  'ATG_1986',
#  'ATG_1987',
#  'ATG_1988',
#  'ATG_1989',
#  'ATG_1990',
#  'ATG_1991',
#  'ATG_1992',
#  'ATG_1993',
#  'ATG_1994',
#  'ATG_1995',
#  'ATG_1996',
#  'ATG_1997',
#  'ATG_1998',
#  'ATG_1999',
#  'ATG_2000',
#  'ATG_2001',
#  'ATG_2002',
#  'ATG_2003',
#  'ATG_2004',
#  'ATG_2005',
#  'ATG_2006',
#  'ATG_2007',
#  'ATG_2008',
#  'ATG_2009',
#  'ATG_2010',
#  'ATG_2011',
#  'ATG_2012',
#  'ATG_2013',
#  'ATG_2014',
#  'ATG_2015',
#  'ATG_2016',
#  'ATG_2017',
#  'ATG_2018',
#  'ATG_2019',
#  'AUS_1960',
#  'AUS_1961',
#  'AUS_1962',
#  'AUS_1963',
#  'AUS_1964',
#  'AUS_1965',
#  'AUS_1966',
#  'AUS_1967',
#  'AUS_1968',
#  'AUS_1969',
#  'AUS_1970',
#  'AUS_1971',
#  'AUS_1972',
#  'AUS_1973',
#  'AUS_1974',
#  'AUS_1975',
#  'AUS_1976',
#  'AUS_1977',
#  'AUS_1978',
#  'AUS_1979',
#  'AUS_1980',
#  'AUS_1981',
#  'AUS_1982',
#  'AUS_1983',
#  'AUS_1984',
#  'AUS_1985',
#  'AUS_1986',
#  'AUS_1987',
#  'AUS_1988',
#  'AUS_1989',
#  'AUS_1990',
#  'AUS_1991',
#  'AUS_1992',
#  'AUS_1993',
#  'AUS_1994',
#  'AUS_1995',
#  'AUS_1996',
#  'AUS_1997',
#  'AUS_1998',
#  'AUS_1999',
#  'AUS_2000',
#  'AUS_2001',
#  'AUS_2002',
#  'AUS_2003',
#  'AUS_2004',
#  'AUS_2005',
#  'AUS_2006',
#  'AUS_2007',
#  'AUS_2008',
#  'AUS_2009',
#  'AUS_2010',
#  'AUS_2011',
#  'AUS_2012',
#  'AUS_2013',
#  'AUS_2014',
#  'AUS_2015',
#  'AUS_2016',
#  'AUS_2017',
#  'AUS_2018',
#  'AUS_2019',
#  'AUT_1960',
#  'AUT_1961',
#  'AUT_1962',
#  'AUT_1963',
#  'AUT_1964',
#  'AUT_1965',
#  'AUT_1966',
#  'AUT_1967',
#  'AUT_1968',
#  'AUT_1969',
#  'AUT_1970',
#  'AUT_1971',
#  'AUT_1972',
#  'AUT_1973',
#  'AUT_1974',
#  'AUT_1975',
#  'AUT_1976',
#  'AUT_1977',
#  'AUT_1978',
#  'AUT_1979',
#  'AUT_1980',
#  'AUT_1981',
#  'AUT_1982',
#  'AUT_1983',
#  'AUT_1984',
#  'AUT_1985',
#  'AUT_1986',
#  'AUT_1987',
#  'AUT_1988',
#  'AUT_1989',
#  'AUT_1990',
#  'AUT_1991',
#  'AUT_1992',
#  'AUT_1993',
#  'AUT_1994',
#  'AUT_1995',
#  'AUT_1996',
#  'AUT_1997',
#  'AUT_1998',
#  'AUT_1999',
#  'AUT_2000',
#  'AUT_2001',
#  'AUT_2002',
#  'AUT_2003',
#  'AUT_2004',
#  'AUT_2005',
#  'AUT_2006',
#  'AUT_2007',
#  'AUT_2008',
#  'AUT_2009',
#  'AUT_2010',
#  'AUT_2011',
#  'AUT_2012',
#  'AUT_2013',
#  'AUT_2014',
#  'AUT_2015',
#  'AUT_2016',
#  'AUT_2017',
#  'AUT_2018',
#  'AUT_2019',
#  'AZE_1990',
#  'AZE_1991',
#  'AZE_1992',
#  'AZE_1993',
#  'AZE_1994',
#  'AZE_1995',
#  'AZE_1996',
#  'AZE_1997',
#  'AZE_1998',
#  'AZE_1999',
#  'AZE_2000',
#  'AZE_2001',
#  'AZE_2002',
#  'AZE_2003',
#  'AZE_2004',
#  'AZE_2005',
#  'AZE_2006',
#  'AZE_2007',
#  'AZE_2008',
#  'AZE_2009',
#  'AZE_2010',
#  'AZE_2011',
#  'AZE_2012',
#  'AZE_2013',
#  'AZE_2014',
#  'AZE_2015',
#  'AZE_2016',
#  'AZE_2017',
#  'AZE_2018',
#  'AZE_2019',
#  'BDI_1962',
#  'BDI_1963',
#  'BDI_1964',
#  'BDI_1965',
#  'BDI_1966',
#  'BDI_1967',
#  'BDI_1968',
#  'BDI_1969',
#  'BDI_1970',
#  'BDI_1971',
#  'BDI_1972',
#  'BDI_1973',
#  'BDI_1974',
#  'BDI_1975',
#  'BDI_1976',
#  'BDI_1977',
#  'BDI_1978',
#  'BDI_1979',
#  'BDI_1980',
#  'BDI_1981',
#  'BDI_1982',
#  'BDI_1983',
#  'BDI_1984',
#  'BDI_1985',
#  'BDI_1986',
#  'BDI_1987',
#  'BDI_1988',
#  'BDI_1989',
#  'BDI_1990',
#  'BDI_1991',
#  'BDI_1992',
#  'BDI_1993',
#  'BDI_1994',
#  'BDI_1995',
#  'BDI_1996',
#  'BDI_1997',
#  'BDI_1998',
#  'BDI_1999',
#  'BDI_2000',
#  'BDI_2001',
#  'BDI_2002',
#  'BDI_2003',
#  'BDI_2004',
#  'BDI_2005',
#  'BDI_2006',
#  'BDI_2007',
#  'BDI_2008',
#  'BDI_2009',
#  'BDI_2010',
#  'BDI_2011',
#  'BDI_2012',
#  'BDI_2013',
#  'BDI_2014',
#  'BDI_2015',
#  'BDI_2016',
#  'BDI_2017',
#  'BDI_2018',
#  'BDI_2019',
#  'BEL_1960',
#  'BEL_1961',
#  'BEL_1962',
#  'BEL_1963',
#  'BEL_1964',
#  'BEL_1965',
#  'BEL_1966',
#  'BEL_1967',
#  'BEL_1968',
#  'BEL_1969',
#  'BEL_1970',
#  'BEL_1971',
#  'BEL_1972',
#  'BEL_1973',
#  'BEL_1974',
#  'BEL_1975',
#  'BEL_1976',
#  'BEL_1977',
#  'BEL_1978',
#  'BEL_1979',
#  'BEL_1980',
#  'BEL_1981',
#  'BEL_1982',
#  'BEL_1983',
#  'BEL_1984',
#  'BEL_1985',
#  'BEL_1986',
#  'BEL_1987',
#  'BEL_1988',
#  'BEL_1989',
#  'BEL_1990',
#  'BEL_1991',
#  'BEL_1992',
#  'BEL_1993',
#  'BEL_1994',
#  'BEL_1995',
#  'BEL_1996',
#  'BEL_1997',
#  'BEL_1998',
#  'BEL_1999',
#  'BEL_2000',
#  'BEL_2001',
#  'BEL_2002',
#  'BEL_2003',
#  'BEL_2004',
#  'BEL_2005',
#  'BEL_2006',
#  'BEL_2007',
#  'BEL_2008',
#  'BEL_2009',
#  'BEL_2010',
#  'BEL_2011',
#  'BEL_2012',
#  'BEL_2013',
#  'BEL_2014',
#  'BEL_2015',
#  'BEL_2016',
#  'BEL_2017',
#  'BEL_2018',
#  'BEL_2019',
#  'BEN_1960',
#  'BEN_1961',
#  'BEN_1962',
#  'BEN_1963',
#  'BEN_1964',
#  'BEN_1965',
#  'BEN_1966',
#  'BEN_1967',
#  'BEN_1968',
#  'BEN_1969',
#  'BEN_1970',
#  'BEN_1971',
#  'BEN_1972',
#  'BEN_1973',
#  'BEN_1974',
#  'BEN_1975',
#  'BEN_1976',
#  'BEN_1977',
#  'BEN_1978',
#  'BEN_1979',
#  'BEN_1980',
#  'BEN_1981',
#  'BEN_1982',
#  'BEN_1983',
#  'BEN_1984',
#  'BEN_1985',
#  'BEN_1986',
#  'BEN_1987',
#  'BEN_1988',
#  'BEN_1989',
#  'BEN_1990',
#  'BEN_1991',
#  'BEN_1992',
#  'BEN_1993',
#  'BEN_1994',
#  'BEN_1995',
#  'BEN_1996',
#  'BEN_1997',
#  'BEN_1998',
#  'BEN_1999',
#  'BEN_2000',
#  'BEN_2001',
#  'BEN_2002',
#  'BEN_2003',
#  'BEN_2004',
#  'BEN_2005',
#  'BEN_2006',
#  'BEN_2007',
#  'BEN_2008',
#  'BEN_2009',
#  'BEN_2010',
#  'BEN_2011',
#  'BEN_2012',
#  'BEN_2013',
#  'BEN_2014',
#  'BEN_2015',
#  'BEN_2016',
#  'BEN_2017',
#  'BEN_2018',
#  'BEN_2019',
#  'BFA_1960',
#  'BFA_1961',
#  'BFA_1962',
#  'BFA_1963',
#  'BFA_1964',
#  'BFA_1965',
#  'BFA_1966',
#  'BFA_1967',
#  'BFA_1968',
#  'BFA_1969',
#  'BFA_1970',
#  'BFA_1971',
#  'BFA_1972',
#  'BFA_1973',
#  'BFA_1974',
#  ...]

# %%
# setting a new index for co2_df
co2_df['new_index'] = co2_index
co2_df
# Out:
#       country_code country_name  year         value new_index
# 0              ABW        Aruba  1960  11092.675000  ABW_1960
# 1              ABW        Aruba  1961  11576.719000  ABW_1961
# 2              ABW        Aruba  1962  12713.489000  ABW_1962
# 3              ABW        Aruba  1963  12178.107000  ABW_1963
# 4              ABW        Aruba  1964  11840.743000  ABW_1964
# ...            ...          ...   ...           ...       ...
# 13948          ZWE     Zimbabwe  2015  12430.000305  ZWE_2015
# 13949          ZWE     Zimbabwe  2016  11020.000458  ZWE_2016
# 13950          ZWE     Zimbabwe  2017  10340.000153  ZWE_2017
# 13951          ZWE     Zimbabwe  2018  12380.000114  ZWE_2018
# 13952          ZWE     Zimbabwe  2019  11760.000229  ZWE_2019
#
# [13953 rows x 5 columns]

# %%
lungcancer_data = 'Resources/lung-cancer-deaths-per-100000-by-sex-1950-2002.csv'
lungcancer_df = pd.read_csv(lungcancer_data)
print(lungcancer_df.shape)
lungcancer_df.head()
# Out:
# (4572, 5)
#     Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 0  Albania  ALB  1987                                      38.99
# 1  Albania  ALB  1988                                      41.27
# 2  Albania  ALB  1989                                      36.56
# 3  Albania  ALB  1992                                      29.70
# 4  Albania  ALB  1993                                      27.44
#
#    age-standardized_death_rate_per_100k_female
# 0                                         5.95
# 1                                         6.97
# 2                                         4.42
# 3                                         5.68
# 4                                         5.41

# %%
print(len(lungcancer_df['Code'].value_counts()))
print(lungcancer_df['Code'].value_counts())
# Out:
# 112
# USA    71
# NLD    71
# JPN    70
# AUS    70
# ESP    70
#        ..
# STP     3
# IRQ     3
# CPV     2
# MNG     2
# LBN     1
# Name: Code, Length: 112, dtype: int64

# %%
# creating new index for lungcancer_df to enable merging dfs
lungcancer_index = []

for i, row in lungcancer_df.iterrows():
    value = f"{lungcancer_df['Code'][i]}_{lungcancer_df['Year'][i]}"
    lungcancer_index.append(value)

lungcancer_index
# Out:
# ['ALB_1987',
#  'ALB_1988',
#  'ALB_1989',
#  'ALB_1992',
#  'ALB_1993',
#  'ALB_1994',
#  'ALB_1995',
#  'ALB_1996',
#  'ALB_1997',
#  'ALB_1998',
#  'ALB_1999',
#  'ALB_2000',
#  'ALB_2001',
#  'ALB_2002',
#  'ALB_2003',
#  'ALB_2004',
#  'ALB_2005',
#  'ALB_2006',
#  'ALB_2007',
#  'ALB_2008',
#  'ALB_2009',
#  'ALB_2010',
#  'ATG_1961',
#  'ATG_1962',
#  'ATG_1963',
#  'ATG_1964',
#  'ATG_1966',
#  'ATG_1969',
#  'ATG_1970',
#  'ATG_1971',
#  'ATG_1972',
#  'ATG_1973',
#  'ATG_1974',
#  'ATG_1975',
#  'ATG_1976',
#  'ATG_1977',
#  'ATG_1978',
#  'ATG_1983',
#  'ATG_1985',
#  'ATG_1986',
#  'ATG_1987',
#  'ATG_1988',
#  'ATG_1989',
#  'ATG_1990',
#  'ATG_1991',
#  'ATG_1992',
#  'ATG_1993',
#  'ATG_1994',
#  'ATG_1995',
#  'ATG_1998',
#  'ATG_1999',
#  'ATG_2000',
#  'ATG_2001',
#  'ATG_2002',
#  'ATG_2003',
#  'ATG_2004',
#  'ATG_2005',
#  'ATG_2006',
#  'ATG_2007',
#  'ATG_2008',
#  'ATG_2009',
#  'ATG_2012',
#  'ATG_2013',
#  'ATG_2014',
#  'ATG_2015',
#  'ATG_2016',
#  'ATG_2017',
#  'ARG_1966',
#  'ARG_1967',
#  'ARG_1968',
#  'ARG_1969',
#  'ARG_1970',
#  'ARG_1977',
#  'ARG_1978',
#  'ARG_1979',
#  'ARG_1980',
#  'ARG_1981',
#  'ARG_1982',
#  'ARG_1983',
#  'ARG_1984',
#  'ARG_1985',
#  'ARG_1986',
#  'ARG_1987',
#  'ARG_1988',
#  'ARG_1989',
#  'ARG_1990',
#  'ARG_1991',
#  'ARG_1992',
#  'ARG_1993',
#  'ARG_1994',
#  'ARG_1995',
#  'ARG_1996',
#  'ARG_1997',
#  'ARG_1998',
#  'ARG_1999',
#  'ARG_2000',
#  'ARG_2001',
#  'ARG_2002',
#  'ARG_2003',
#  'ARG_2004',
#  'ARG_2005',
#  'ARG_2006',
#  'ARG_2007',
#  'ARG_2008',
#  'ARG_2009',
#  'ARG_2010',
#  'ARG_2011',
#  'ARG_2012',
#  'ARG_2013',
#  'ARG_2014',
#  'ARG_2015',
#  'ARG_2016',
#  'ARG_2017',
#  'ARG_2018',
#  'ARG_2019',
#  'ARM_1981',
#  'ARM_1982',
#  'ARM_1985',
#  'ARM_1986',
#  'ARM_1987',
#  'ARM_1988',
#  'ARM_1989',
#  'ARM_1990',
#  'ARM_1991',
#  'ARM_1992',
#  'ARM_1993',
#  'ARM_1994',
#  'ARM_1995',
#  'ARM_1996',
#  'ARM_1997',
#  'ARM_1998',
#  'ARM_1999',
#  'ARM_2000',
#  'ARM_2001',
#  'ARM_2002',
#  'ARM_2003',
#  'ARM_2006',
#  'ARM_2007',
#  'ARM_2008',
#  'ARM_2009',
#  'ARM_2010',
#  'ARM_2011',
#  'ARM_2012',
#  'ARM_2013',
#  'ARM_2014',
#  'ARM_2015',
#  'ARM_2016',
#  'ARM_2017',
#  'ARM_2018',
#  'ARM_2019',
#  'AUS_1950',
#  'AUS_1951',
#  'AUS_1952',
#  'AUS_1953',
#  'AUS_1954',
#  'AUS_1955',
#  'AUS_1956',
#  'AUS_1957',
#  'AUS_1958',
#  'AUS_1959',
#  'AUS_1960',
#  'AUS_1961',
#  'AUS_1962',
#  'AUS_1963',
#  'AUS_1964',
#  'AUS_1965',
#  'AUS_1966',
#  'AUS_1967',
#  'AUS_1968',
#  'AUS_1969',
#  'AUS_1970',
#  'AUS_1971',
#  'AUS_1972',
#  'AUS_1973',
#  'AUS_1974',
#  'AUS_1975',
#  'AUS_1976',
#  'AUS_1977',
#  'AUS_1978',
#  'AUS_1979',
#  'AUS_1980',
#  'AUS_1981',
#  'AUS_1982',
#  'AUS_1983',
#  'AUS_1984',
#  'AUS_1985',
#  'AUS_1986',
#  'AUS_1987',
#  'AUS_1988',
#  'AUS_1989',
#  'AUS_1990',
#  'AUS_1991',
#  'AUS_1992',
#  'AUS_1993',
#  'AUS_1994',
#  'AUS_1995',
#  'AUS_1996',
#  'AUS_1997',
#  'AUS_1998',
#  'AUS_1999',
#  'AUS_2000',
#  'AUS_2001',
#  'AUS_2002',
#  'AUS_2003',
#  'AUS_2004',
#  'AUS_2006',
#  'AUS_2007',
#  'AUS_2008',
#  'AUS_2009',
#  'AUS_2010',
#  'AUS_2011',
#  'AUS_2012',
#  'AUS_2013',
#  'AUS_2014',
#  'AUS_2015',
#  'AUS_2016',
#  'AUS_2017',
#  'AUS_2018',
#  'AUS_2019',
#  'AUS_2020',
#  'AUT_1955',
#  'AUT_1956',
#  'AUT_1957',
#  'AUT_1958',
#  'AUT_1959',
#  'AUT_1960',
#  'AUT_1961',
#  'AUT_1962',
#  'AUT_1963',
#  'AUT_1964',
#  'AUT_1965',
#  'AUT_1966',
#  'AUT_1967',
#  'AUT_1968',
#  'AUT_1969',
#  'AUT_1970',
#  'AUT_1971',
#  'AUT_1972',
#  'AUT_1973',
#  'AUT_1974',
#  'AUT_1975',
#  'AUT_1976',
#  'AUT_1977',
#  'AUT_1978',
#  'AUT_1979',
#  'AUT_1980',
#  'AUT_1981',
#  'AUT_1982',
#  'AUT_1983',
#  'AUT_1984',
#  'AUT_1985',
#  'AUT_1986',
#  'AUT_1987',
#  'AUT_1988',
#  'AUT_1989',
#  'AUT_1990',
#  'AUT_1991',
#  'AUT_1992',
#  'AUT_1993',
#  'AUT_1994',
#  'AUT_1995',
#  'AUT_1996',
#  'AUT_1997',
#  'AUT_1998',
#  'AUT_1999',
#  'AUT_2000',
#  'AUT_2001',
#  'AUT_2002',
#  'AUT_2003',
#  'AUT_2004',
#  'AUT_2005',
#  'AUT_2006',
#  'AUT_2007',
#  'AUT_2008',
#  'AUT_2009',
#  'AUT_2010',
#  'AUT_2011',
#  'AUT_2012',
#  'AUT_2013',
#  'AUT_2014',
#  'AUT_2015',
#  'AUT_2016',
#  'AUT_2017',
#  'AUT_2018',
#  'AUT_2019',
#  'AUT_2020',
#  'AZE_1981',
#  'AZE_1982',
#  'AZE_1985',
#  'AZE_1986',
#  'AZE_1987',
#  'AZE_1988',
#  'AZE_1989',
#  'AZE_1990',
#  'AZE_1991',
#  'AZE_1992',
#  'AZE_1993',
#  'AZE_1994',
#  'AZE_1995',
#  'AZE_1996',
#  'AZE_1997',
#  'AZE_1998',
#  'AZE_1999',
#  'AZE_2000',
#  'AZE_2001',
#  'AZE_2002',
#  'AZE_2003',
#  'AZE_2004',
#  'AZE_2007',
#  'BHS_1972',
#  'BHS_1975',
#  'BHS_1979',
#  'BHS_1980',
#  'BHS_1981',
#  'BHS_1984',
#  'BHS_1985',
#  'BHS_1987',
#  'BHS_1993',
#  'BHS_1994',
#  'BHS_1995',
#  'BHS_1996',
#  'BHS_1997',
#  'BHS_1998',
#  'BHS_1999',
#  'BHS_2000',
#  'BHS_2001',
#  'BHS_2002',
#  'BHS_2003',
#  'BHS_2004',
#  'BHS_2005',
#  'BHS_2006',
#  'BHS_2007',
#  'BHS_2008',
#  'BHS_2009',
#  'BHS_2010',
#  'BHS_2011',
#  'BHS_2012',
#  'BHS_2013',
#  'BHS_2014',
#  'BHS_2015',
#  'BHR_1985',
#  'BHR_1987',
#  'BHR_1988',
#  'BHR_1997',
#  'BHR_1998',
#  'BHR_1999',
#  'BHR_2000',
#  'BHR_2001',
#  'BHR_2002',
#  'BHR_2003',
#  'BHR_2004',
#  'BHR_2005',
#  'BHR_2006',
#  'BHR_2007',
#  'BHR_2008',
#  'BHR_2009',
#  'BHR_2010',
#  'BHR_2011',
#  'BHR_2012',
#  'BHR_2013',
#  'BHR_2014',
#  'BRB_1960',
#  'BRB_1961',
#  'BRB_1962',
#  'BRB_1963',
#  'BRB_1964',
#  'BRB_1966',
#  'BRB_1967',
#  'BRB_1968',
#  'BRB_1969',
#  'BRB_1970',
#  'BRB_1971',
#  'BRB_1972',
#  'BRB_1973',
#  'BRB_1974',
#  'BRB_1975',
#  'BRB_1976',
#  'BRB_1977',
#  'BRB_1978',
#  'BRB_1979',
#  'BRB_1980',
#  'BRB_1981',
#  'BRB_1982',
#  'BRB_1983',
#  'BRB_1984',
#  'BRB_1985',
#  'BRB_1986',
#  'BRB_1987',
#  'BRB_1988',
#  'BRB_1989',
#  'BRB_1990',
#  'BRB_1991',
#  'BRB_1992',
#  'BRB_1993',
#  'BRB_1994',
#  'BRB_1995',
#  'BRB_2000',
#  'BRB_2001',
#  'BRB_2002',
#  'BRB_2003',
#  'BRB_2004',
#  'BRB_2005',
#  'BRB_2006',
#  'BRB_2007',
#  'BRB_2008',
#  'BRB_2009',
#  'BRB_2010',
#  'BRB_2011',
#  'BRB_2012',
#  'BRB_2013',
#  'BLR_1981',
#  'BLR_1982',
#  'BLR_1985',
#  'BLR_1986',
#  'BLR_1987',
#  'BLR_1988',
#  'BLR_1989',
#  'BLR_1990',
#  'BLR_1991',
#  'BLR_1992',
#  'BLR_1993',
#  'BLR_1994',
#  'BLR_1995',
#  'BLR_1996',
#  'BLR_1997',
#  'BLR_1998',
#  'BLR_1999',
#  'BLR_2000',
#  'BLR_2001',
#  'BLR_2002',
#  'BLR_2003',
#  'BLR_2007',
#  'BLR_2008',
#  'BLR_2009',
#  'BLR_2010',
#  'BLR_2011',
#  'BLR_2013',
#  'BLR_2014',
#  'BLR_2018',
#  'BEL_1954',
#  'BEL_1955',
#  'BEL_1956',
#  'BEL_1957',
#  'BEL_1958',
#  'BEL_1959',
#  'BEL_1960',
#  'BEL_1961',
#  'BEL_1962',
#  'BEL_1963',
#  'BEL_1964',
#  'BEL_1965',
#  'BEL_1966',
#  'BEL_1967',
#  'BEL_1968',
#  'BEL_1969',
#  'BEL_1970',
#  'BEL_1971',
#  'BEL_1972',
#  'BEL_1973',
#  'BEL_1974',
#  'BEL_1975',
#  'BEL_1976',
#  'BEL_1977',
#  'BEL_1978',
#  'BEL_1979',
#  'BEL_1980',
#  'BEL_1981',
#  'BEL_1982',
#  'BEL_1983',
#  'BEL_1984',
#  'BEL_1985',
#  'BEL_1986',
#  'BEL_1987',
#  'BEL_1988',
#  'BEL_1989',
#  'BEL_1990',
#  'BEL_1991',
#  'BEL_1992',
#  'BEL_1993',
#  'BEL_1994',
#  'BEL_1995',
#  'BEL_1996',
#  'BEL_1997',
#  'BEL_1998',
#  'BEL_1999',
#  'BEL_2000',
#  'BEL_2001',
#  'BEL_2002',
#  'BEL_2003',
#  'BEL_2004',
#  'BEL_2005',
#  'BEL_2006',
#  'BEL_2007',
#  'BEL_2008',
#  'BEL_2009',
#  'BEL_2010',
#  'BEL_2011',
#  'BEL_2012',
#  'BEL_2013',
#  'BEL_2014',
#  'BEL_2015',
#  'BEL_2016',
#  'BEL_2017',
#  'BEL_2018',
#  'BLZ_1964',
#  'BLZ_1965',
#  'BLZ_1966',
#  'BLZ_1967',
#  'BLZ_1968',
#  'BLZ_1969',
#  'BLZ_1970',
#  'BLZ_1971',
#  'BLZ_1972',
#  'BLZ_1973',
#  'BLZ_1974',
#  'BLZ_1975',
#  'BLZ_1976',
#  'BLZ_1977',
#  'BLZ_1978',
#  'BLZ_1979',
#  'BLZ_1980',
#  'BLZ_1982',
#  'BLZ_1983',
#  'BLZ_1984',
#  'BLZ_1986',
#  'BLZ_1987',
#  'BLZ_1989',
#  'BLZ_1990',
#  'BLZ_1991',
#  'BLZ_1993',
#  'BLZ_1994',
#  'BLZ_1995',
#  'BLZ_1996',
#  'BLZ_1997',
#  'BLZ_1998',
#  'BLZ_1999',
#  'BLZ_2000',
#  'BLZ_2001',
#  'BLZ_2002',
#  'BLZ_2003',
#  'BLZ_2004',
#  'BLZ_2005',
#  'BLZ_2006',
#  'BLZ_2007',
#  'BLZ_2008',
#  'BLZ_2009',
#  'BLZ_2010',
#  'BLZ_2011',
#  'BLZ_2012',
#  'BLZ_2013',
#  'BLZ_2014',
#  'BLZ_2015',
#  'BLZ_2016',
#  'BIH_1985',
#  'BIH_1986',
#  'BIH_1987',
#  'BIH_1988',
#  'BIH_1989',
#  'BIH_1990',
#  'BIH_1991',
#  'BIH_2011',
#  'BIH_2014',
#  'BIH_2016',
#  'BIH_2017',
#  'BIH_2018',
#  'BIH_2019',
#  'BIH_2020',
#  'BRA_1979',
#  'BRA_1980',
#  'BRA_1981',
#  'BRA_1982',
#  'BRA_1983',
#  'BRA_1984',
#  'BRA_1985',
#  'BRA_1986',
#  'BRA_1987',
#  'BRA_1988',
#  'BRA_1989',
#  'BRA_1990',
#  'BRA_1991',
#  'BRA_1992',
#  'BRA_1993',
#  'BRA_1994',
#  'BRA_1995',
#  'BRA_1996',
#  'BRA_1997',
#  'BRA_1998',
#  'BRA_1999',
#  'BRA_2000',
#  'BRA_2001',
#  'BRA_2002',
#  'BRA_2003',
#  'BRA_2004',
#  'BRA_2005',
#  'BRA_2006',
#  'BRA_2007',
#  'BRA_2008',
#  'BRA_2009',
#  'BRA_2010',
#  'BRA_2011',
#  'BRA_2012',
#  'BRA_2013',
#  'BRA_2014',
#  'BRA_2015',
#  'BRA_2016',
#  'BRA_2017',
#  'BRA_2018',
#  'BRA_2019',
#  'BRN_1996',
#  'BRN_1997',
#  'BRN_1998',
#  'BRN_1999',
#  'BRN_2000',
#  'BRN_2001',
#  'BRN_2002',
#  'BRN_2003',
#  'BRN_2004',
#  'BRN_2005',
#  'BRN_2006',
#  'BRN_2007',
#  'BRN_2008',
#  'BRN_2009',
#  'BRN_2010',
#  'BRN_2011',
#  'BRN_2012',
#  'BRN_2013',
#  'BRN_2014',
#  'BRN_2015',
#  'BRN_2016',
#  'BRN_2017',
#  'BRN_2018',
#  'BRN_2019',
#  'BGR_1964',
#  'BGR_1965',
#  'BGR_1966',
#  'BGR_1967',
#  'BGR_1968',
#  'BGR_1969',
#  'BGR_1970',
#  'BGR_1971',
#  'BGR_1972',
#  'BGR_1973',
#  'BGR_1974',
#  'BGR_1975',
#  'BGR_1976',
#  'BGR_1977',
#  'BGR_1978',
#  'BGR_1979',
#  'BGR_1980',
#  'BGR_1981',
#  'BGR_1982',
#  'BGR_1983',
#  'BGR_1984',
#  'BGR_1985',
#  'BGR_1986',
#  'BGR_1987',
#  'BGR_1988',
#  'BGR_1989',
#  'BGR_1990',
#  'BGR_1991',
#  'BGR_1992',
#  'BGR_1993',
#  'BGR_1994',
#  'BGR_1995',
#  'BGR_1996',
#  'BGR_1997',
#  'BGR_1998',
#  'BGR_1999',
#  'BGR_2000',
#  'BGR_2001',
#  'BGR_2002',
#  'BGR_2003',
#  'BGR_2004',
#  'BGR_2005',
#  'BGR_2006',
#  'BGR_2007',
#  'BGR_2008',
#  'BGR_2009',
#  'BGR_2010',
#  'BGR_2011',
#  'BGR_2012',
#  'BGR_2013',
#  'BGR_2014',
#  'BGR_2015',
#  'BGR_2016',
#  'BGR_2017',
#  'BGR_2018',
#  'BGR_2019',
#  'CAN_1950',
#  'CAN_1951',
#  'CAN_1952',
#  'CAN_1953',
#  'CAN_1954',
#  'CAN_1955',
#  'CAN_1956',
#  'CAN_1957',
#  'CAN_1958',
#  'CAN_1959',
#  'CAN_1960',
#  'CAN_1961',
#  'CAN_1962',
#  'CAN_1963',
#  'CAN_1964',
#  'CAN_1965',
#  'CAN_1966',
#  'CAN_1967',
#  'CAN_1968',
#  'CAN_1969',
#  'CAN_1970',
#  'CAN_1971',
#  'CAN_1972',
#  'CAN_1973',
#  'CAN_1974',
#  'CAN_1975',
#  'CAN_1976',
#  'CAN_1977',
#  'CAN_1978',
#  'CAN_1979',
#  'CAN_1980',
#  'CAN_1981',
#  'CAN_1982',
#  'CAN_1983',
#  'CAN_1984',
#  'CAN_1985',
#  'CAN_1986',
#  'CAN_1987',
#  'CAN_1988',
#  'CAN_1989',
#  'CAN_1990',
#  'CAN_1991',
#  'CAN_1992',
#  'CAN_1993',
#  'CAN_1994',
#  'CAN_1995',
#  'CAN_1996',
#  'CAN_1997',
#  'CAN_1998',
#  'CAN_1999',
#  'CAN_2000',
#  'CAN_2001',
#  'CAN_2002',
#  'CAN_2003',
#  'CAN_2004',
#  'CAN_2005',
#  'CAN_2006',
#  'CAN_2007',
#  'CAN_2008',
#  'CAN_2009',
#  'CAN_2010',
#  'CAN_2011',
#  'CAN_2012',
#  'CAN_2013',
#  'CAN_2014',
#  'CAN_2015',
#  'CAN_2016',
#  'CAN_2017',
#  'CAN_2018',
#  'CAN_2019',
#  'CPV_1980',
#  'CPV_2011',
#  'CHL_1955',
#  'CHL_1956',
#  'CHL_1957',
#  'CHL_1958',
#  'CHL_1959',
#  'CHL_1960',
#  'CHL_1961',
#  'CHL_1962',
#  'CHL_1963',
#  'CHL_1964',
#  'CHL_1965',
#  'CHL_1966',
#  'CHL_1967',
#  'CHL_1968',
#  'CHL_1969',
#  'CHL_1970',
#  'CHL_1971',
#  'CHL_1972',
#  'CHL_1973',
#  'CHL_1974',
#  'CHL_1975',
#  'CHL_1976',
#  'CHL_1977',
#  'CHL_1978',
#  'CHL_1979',
#  'CHL_1980',
#  'CHL_1981',
#  'CHL_1982',
#  'CHL_1983',
#  'CHL_1984',
#  'CHL_1985',
#  'CHL_1986',
#  'CHL_1987',
#  'CHL_1988',
#  'CHL_1989',
#  'CHL_1990',
#  'CHL_1991',
#  'CHL_1992',
#  'CHL_1993',
#  'CHL_1994',
#  'CHL_1995',
#  'CHL_1996',
#  'CHL_1997',
#  'CHL_1998',
#  'CHL_1999',
#  'CHL_2000',
#  'CHL_2001',
#  'CHL_2002',
#  'CHL_2003',
#  'CHL_2004',
#  'CHL_2005',
#  'CHL_2006',
#  'CHL_2007',
#  'CHL_2008',
#  'CHL_2009',
#  'CHL_2010',
#  'CHL_2011',
#  'CHL_2012',
#  'CHL_2013',
#  'CHL_2014',
#  'CHL_2015',
#  'CHL_2016',
#  'CHL_2017',
#  'CHL_2018',
#  'COL_1953',
#  'COL_1954',
#  'COL_1955',
#  'COL_1956',
#  'COL_1957',
#  'COL_1958',
#  'COL_1959',
#  'COL_1960',
#  'COL_1961',
#  'COL_1962',
#  'COL_1963',
#  'COL_1964',
#  'COL_1965',
#  'COL_1966',
#  'COL_1967',
#  'COL_1968',
#  'COL_1969',
#  'COL_1972',
#  'COL_1974',
#  'COL_1975',
#  'COL_1976',
#  'COL_1977',
#  'COL_1984',
#  'COL_1985',
#  'COL_1986',
#  'COL_1987',
#  'COL_1988',
#  'COL_1989',
#  'COL_1990',
#  'COL_1991',
#  'COL_1992',
#  'COL_1993',
#  'COL_1994',
#  'COL_1995',
#  'COL_1996',
#  'COL_1997',
#  'COL_1998',
#  'COL_1999',
#  'COL_2000',
#  'COL_2001',
#  'COL_2002',
#  'COL_2003',
#  'COL_2004',
#  'COL_2005',
#  'COL_2006',
#  'COL_2007',
#  'COL_2008',
#  'COL_2009',
#  'COL_2010',
#  'COL_2011',
#  'COL_2012',
#  'COL_2013',
#  'COL_2014',
#  'COL_2015',
#  'COL_2016',
#  'COL_2017',
#  'COL_2018',
#  'COL_2019',
#  'CRI_1961',
#  'CRI_1962',
#  'CRI_1963',
#  'CRI_1964',
#  'CRI_1965',
#  'CRI_1966',
#  'CRI_1967',
#  'CRI_1968',
#  'CRI_1969',
#  'CRI_1970',
#  'CRI_1971',
#  'CRI_1972',
#  'CRI_1973',
#  'CRI_1974',
#  'CRI_1975',
#  'CRI_1976',
#  'CRI_1977',
#  'CRI_1978',
#  'CRI_1979',
#  'CRI_1980',
#  'CRI_1981',
#  'CRI_1982',
#  'CRI_1983',
#  'CRI_1984',
#  'CRI_1985',
#  'CRI_1986',
#  'CRI_1987',
#  'CRI_1988',
#  'CRI_1989',
#  'CRI_1990',
#  'CRI_1991',
#  'CRI_1992',
#  'CRI_1993',
#  'CRI_1994',
#  'CRI_1995',
#  'CRI_1996',
#  'CRI_1997',
#  'CRI_1998',
#  'CRI_1999',
#  'CRI_2000',
#  'CRI_2001',
#  'CRI_2002',
#  'CRI_2003',
#  'CRI_2004',
#  'CRI_2005',
#  'CRI_2006',
#  'CRI_2007',
#  'CRI_2008',
#  'CRI_2009',
#  'CRI_2010',
#  'CRI_2011',
#  'CRI_2012',
#  'CRI_2013',
#  'CRI_2014',
#  'CRI_2015',
#  'CRI_2016',
#  'CRI_2017',
#  'CRI_2018',
#  'CRI_2019',
#  'CRI_2020',
#  'HRV_1985',
#  'HRV_1986',
#  'HRV_1987',
#  'HRV_1988',
#  'HRV_1989',
#  'HRV_1990',
#  'HRV_1991',
#  'HRV_1992',
#  'HRV_1993',
#  'HRV_1994',
#  'HRV_1995',
#  'HRV_1996',
#  'HRV_1997',
#  'HRV_1998',
#  'HRV_1999',
#  'HRV_2000',
#  'HRV_2001',
#  'HRV_2002',
#  'HRV_2003',
#  'HRV_2004',
#  'HRV_2005',
#  'HRV_2006',
#  'HRV_2007',
#  'HRV_2008',
#  'HRV_2009',
#  'HRV_2010',
#  'HRV_2011',
#  'HRV_2012',
#  'HRV_2013',
#  'HRV_2014',
#  'HRV_2015',
#  'HRV_2016',
#  'HRV_2017',
#  'HRV_2019',
#  'CUB_1964',
#  'CUB_1968',
#  'CUB_1969',
#  'CUB_1970',
#  'CUB_1971',
#  'CUB_1972',
#  'CUB_1973',
#  'CUB_1974',
#  'CUB_1975',
#  'CUB_1976',
#  'CUB_1977',
#  'CUB_1978',
#  'CUB_1979',
#  'CUB_1980',
#  'CUB_1981',
#  'CUB_1982',
#  'CUB_1983',
#  'CUB_1984',
#  'CUB_1985',
#  'CUB_1986',
#  'CUB_1987',
#  'CUB_1988',
#  'CUB_1989',
#  'CUB_1990',
#  ...]

# %%
# setting a new index for lungcancer_df
lungcancer_df['new_index'] = lungcancer_index
lungcancer_df
# = lungcancer_df.set_index(lungcancer_df['new_index']).drop(columns=['new_index'])
# lungcancer_df
# Out:
#          Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 0       Albania  ALB  1987                                      38.99
# 1       Albania  ALB  1988                                      41.27
# 2       Albania  ALB  1989                                      36.56
# 3       Albania  ALB  1992                                      29.70
# 4       Albania  ALB  1993                                      27.44
# ...         ...  ...   ...                                        ...
# 4567  Venezuela  VEN  2012                                      19.65
# 4568  Venezuela  VEN  2013                                      18.64
# 4569  Venezuela  VEN  2014                                      19.58
# 4570  Venezuela  VEN  2015                                      18.15
# 4571  Venezuela  VEN  2016                                      17.47
#
#       age-standardized_death_rate_per_100k_female new_index
# 0                                            5.95  ALB_1987
# 1                                            6.97  ALB_1988
# 2                                            4.42  ALB_1989
# 3                                            5.68  ALB_1992
# 4                                            5.41  ALB_1993
# ...                                           ...       ...
# 4567                                        11.13  VEN_2012
# 4568                                        11.08  VEN_2013
# 4569                                        11.09  VEN_2014
# 4570                                        11.25  VEN_2015
# 4571                                        10.50  VEN_2016
#
# [4572 rows x 6 columns]

# %%
cigarettes_data = 'Resources/sales-of-cigarettes-per-adult-per-day.csv'
cigarettes_df = pd.read_csv(cigarettes_data)
print(cigarettes_df.shape)
cigarettes_df.head()
# Out:
# (2767, 4)
#     Entity Code  Year  \
# 0  Armenia  ARM  1988
# 1  Armenia  ARM  1989
# 2  Armenia  ARM  1990
# 3  Armenia  ARM  1991
# 4  Armenia  ARM  1992
#
#    Sales of cigarettes per adult per day (International Smoking Statistics (2017))
# 0                                               12.0
# 1                                               11.6
# 2                                               11.9
# 3                                                9.3
# 4                                                4.9

# %%
print(len(cigarettes_df['Code'].value_counts()))
print(cigarettes_df['Code'].value_counts())
# Out:
# 44
# USA         115
# GBR         110
# ITA          98
# FRA          98
# JPN          96
# GRC          93
# IRL          92
# CAN          91
# AUS          91
# DNK          91
# BEL          91
# NZL          90
# FIN          90
# DEU          87
# ESP          87
# SWE          87
# NOR          85
# NLD          84
# ISL          84
# AUT          82
# HUN          78
# CHE          76
# PRT          74
# POL          71
# ROU          70
# BGR          58
# ISR          55
# OWID_CZS     50
# OWID_YGS     47
# LVA          42
# CZE          33
# SVK          32
# LTU          27
# EST          27
# SVN          21
# HRV          21
# RUS          17
# KAZ          13
# MDA          12
# GEO          12
# KGZ          11
# BLR          11
# AZE          11
# ARM          11
# Name: Code, dtype: int64

# %%
# creating new index for cigarettes_df to enable merging dfs
cigarettes_index = []

for i, row in cigarettes_df.iterrows():
    value = f"{cigarettes_df['Code'][i]}_{cigarettes_df['Year'][i]}"
    cigarettes_index.append(value)

cigarettes_index
# Out:
# ['ARM_1988',
#  'ARM_1989',
#  'ARM_1990',
#  'ARM_1991',
#  'ARM_1992',
#  'ARM_1993',
#  'ARM_1994',
#  'ARM_1995',
#  'ARM_1996',
#  'ARM_1997',
#  'ARM_1998',
#  'AUS_1920',
#  'AUS_1921',
#  'AUS_1922',
#  'AUS_1923',
#  'AUS_1924',
#  'AUS_1925',
#  'AUS_1926',
#  'AUS_1927',
#  'AUS_1928',
#  'AUS_1929',
#  'AUS_1930',
#  'AUS_1931',
#  'AUS_1932',
#  'AUS_1933',
#  'AUS_1934',
#  'AUS_1935',
#  'AUS_1936',
#  'AUS_1937',
#  'AUS_1938',
#  'AUS_1939',
#  'AUS_1940',
#  'AUS_1941',
#  'AUS_1942',
#  'AUS_1943',
#  'AUS_1944',
#  'AUS_1945',
#  'AUS_1946',
#  'AUS_1947',
#  'AUS_1948',
#  'AUS_1949',
#  'AUS_1950',
#  'AUS_1951',
#  'AUS_1952',
#  'AUS_1953',
#  'AUS_1954',
#  'AUS_1955',
#  'AUS_1956',
#  'AUS_1957',
#  'AUS_1958',
#  'AUS_1959',
#  'AUS_1960',
#  'AUS_1961',
#  'AUS_1962',
#  'AUS_1963',
#  'AUS_1964',
#  'AUS_1965',
#  'AUS_1966',
#  'AUS_1967',
#  'AUS_1968',
#  'AUS_1969',
#  'AUS_1970',
#  'AUS_1971',
#  'AUS_1972',
#  'AUS_1973',
#  'AUS_1974',
#  'AUS_1975',
#  'AUS_1976',
#  'AUS_1977',
#  'AUS_1978',
#  'AUS_1979',
#  'AUS_1980',
#  'AUS_1981',
#  'AUS_1982',
#  'AUS_1983',
#  'AUS_1984',
#  'AUS_1985',
#  'AUS_1986',
#  'AUS_1987',
#  'AUS_1988',
#  'AUS_1989',
#  'AUS_1990',
#  'AUS_1991',
#  'AUS_1992',
#  'AUS_1993',
#  'AUS_1994',
#  'AUS_1995',
#  'AUS_1996',
#  'AUS_1997',
#  'AUS_1998',
#  'AUS_1999',
#  'AUS_2000',
#  'AUS_2001',
#  'AUS_2002',
#  'AUS_2003',
#  'AUS_2004',
#  'AUS_2005',
#  'AUS_2006',
#  'AUS_2007',
#  'AUS_2008',
#  'AUS_2009',
#  'AUS_2010',
#  'AUT_1923',
#  'AUT_1924',
#  'AUT_1925',
#  'AUT_1926',
#  'AUT_1927',
#  'AUT_1928',
#  'AUT_1929',
#  'AUT_1930',
#  'AUT_1931',
#  'AUT_1932',
#  'AUT_1933',
#  'AUT_1934',
#  'AUT_1935',
#  'AUT_1936',
#  'AUT_1937',
#  'AUT_1938',
#  'AUT_1939',
#  'AUT_1940',
#  'AUT_1941',
#  'AUT_1942',
#  'AUT_1943',
#  'AUT_1944',
#  'AUT_1945',
#  'AUT_1946',
#  'AUT_1947',
#  'AUT_1948',
#  'AUT_1949',
#  'AUT_1950',
#  'AUT_1951',
#  'AUT_1952',
#  'AUT_1953',
#  'AUT_1954',
#  'AUT_1955',
#  'AUT_1956',
#  'AUT_1957',
#  'AUT_1958',
#  'AUT_1959',
#  'AUT_1960',
#  'AUT_1961',
#  'AUT_1962',
#  'AUT_1963',
#  'AUT_1964',
#  'AUT_1965',
#  'AUT_1966',
#  'AUT_1967',
#  'AUT_1968',
#  'AUT_1969',
#  'AUT_1970',
#  'AUT_1971',
#  'AUT_1972',
#  'AUT_1973',
#  'AUT_1974',
#  'AUT_1975',
#  'AUT_1976',
#  'AUT_1977',
#  'AUT_1978',
#  'AUT_1979',
#  'AUT_1980',
#  'AUT_1981',
#  'AUT_1982',
#  'AUT_1983',
#  'AUT_1984',
#  'AUT_1985',
#  'AUT_1986',
#  'AUT_1987',
#  'AUT_1988',
#  'AUT_1989',
#  'AUT_1990',
#  'AUT_1991',
#  'AUT_1992',
#  'AUT_1993',
#  'AUT_1994',
#  'AUT_1995',
#  'AUT_1996',
#  'AUT_1997',
#  'AUT_1998',
#  'AUT_1999',
#  'AUT_2000',
#  'AUT_2001',
#  'AUT_2002',
#  'AUT_2003',
#  'AUT_2004',
#  'AZE_1988',
#  'AZE_1989',
#  'AZE_1990',
#  'AZE_1991',
#  'AZE_1992',
#  'AZE_1993',
#  'AZE_1994',
#  'AZE_1995',
#  'AZE_1996',
#  'AZE_1997',
#  'AZE_1998',
#  'BLR_1988',
#  'BLR_1989',
#  'BLR_1990',
#  'BLR_1991',
#  'BLR_1992',
#  'BLR_1993',
#  'BLR_1994',
#  'BLR_1995',
#  'BLR_1996',
#  'BLR_1997',
#  'BLR_1998',
#  'BEL_1921',
#  'BEL_1922',
#  'BEL_1923',
#  'BEL_1924',
#  'BEL_1925',
#  'BEL_1926',
#  'BEL_1927',
#  'BEL_1928',
#  'BEL_1929',
#  'BEL_1930',
#  'BEL_1931',
#  'BEL_1932',
#  'BEL_1933',
#  'BEL_1934',
#  'BEL_1935',
#  'BEL_1936',
#  'BEL_1937',
#  'BEL_1938',
#  'BEL_1939',
#  'BEL_1940',
#  'BEL_1941',
#  'BEL_1942',
#  'BEL_1943',
#  'BEL_1944',
#  'BEL_1945',
#  'BEL_1946',
#  'BEL_1947',
#  'BEL_1948',
#  'BEL_1949',
#  'BEL_1950',
#  'BEL_1951',
#  'BEL_1952',
#  'BEL_1953',
#  'BEL_1954',
#  'BEL_1955',
#  'BEL_1956',
#  'BEL_1957',
#  'BEL_1958',
#  'BEL_1959',
#  'BEL_1960',
#  'BEL_1961',
#  'BEL_1962',
#  'BEL_1963',
#  'BEL_1964',
#  'BEL_1965',
#  'BEL_1966',
#  'BEL_1967',
#  'BEL_1968',
#  'BEL_1969',
#  'BEL_1970',
#  'BEL_1971',
#  'BEL_1972',
#  'BEL_1973',
#  'BEL_1974',
#  'BEL_1975',
#  'BEL_1976',
#  'BEL_1977',
#  'BEL_1978',
#  'BEL_1979',
#  'BEL_1980',
#  'BEL_1981',
#  'BEL_1982',
#  'BEL_1983',
#  'BEL_1984',
#  'BEL_1985',
#  'BEL_1986',
#  'BEL_1987',
#  'BEL_1988',
#  'BEL_1989',
#  'BEL_1990',
#  'BEL_1991',
#  'BEL_1992',
#  'BEL_1993',
#  'BEL_1994',
#  'BEL_1995',
#  'BEL_1996',
#  'BEL_1997',
#  'BEL_1998',
#  'BEL_1999',
#  'BEL_2000',
#  'BEL_2001',
#  'BEL_2002',
#  'BEL_2003',
#  'BEL_2004',
#  'BEL_2005',
#  'BEL_2006',
#  'BEL_2007',
#  'BEL_2008',
#  'BEL_2009',
#  'BEL_2010',
#  'BEL_2011',
#  'BGR_1913',
#  'BGR_1920',
#  'BGR_1921',
#  'BGR_1922',
#  'BGR_1923',
#  'BGR_1960',
#  'BGR_1961',
#  'BGR_1962',
#  'BGR_1963',
#  'BGR_1964',
#  'BGR_1965',
#  'BGR_1966',
#  'BGR_1967',
#  'BGR_1968',
#  'BGR_1969',
#  'BGR_1970',
#  'BGR_1971',
#  'BGR_1972',
#  'BGR_1973',
#  'BGR_1974',
#  'BGR_1975',
#  'BGR_1976',
#  'BGR_1977',
#  'BGR_1978',
#  'BGR_1979',
#  'BGR_1980',
#  'BGR_1981',
#  'BGR_1982',
#  'BGR_1983',
#  'BGR_1984',
#  'BGR_1985',
#  'BGR_1986',
#  'BGR_1987',
#  'BGR_1988',
#  'BGR_1989',
#  'BGR_1990',
#  'BGR_1991',
#  'BGR_1992',
#  'BGR_1993',
#  'BGR_1994',
#  'BGR_1995',
#  'BGR_1996',
#  'BGR_1997',
#  'BGR_1998',
#  'BGR_1999',
#  'BGR_2000',
#  'BGR_2001',
#  'BGR_2002',
#  'BGR_2003',
#  'BGR_2004',
#  'BGR_2007',
#  'BGR_2008',
#  'BGR_2009',
#  'BGR_2010',
#  'BGR_2011',
#  'BGR_2012',
#  'BGR_2013',
#  'BGR_2014',
#  'CAN_1920',
#  'CAN_1921',
#  'CAN_1922',
#  'CAN_1923',
#  'CAN_1924',
#  'CAN_1925',
#  'CAN_1926',
#  'CAN_1927',
#  'CAN_1928',
#  'CAN_1929',
#  'CAN_1930',
#  'CAN_1931',
#  'CAN_1932',
#  'CAN_1933',
#  'CAN_1934',
#  'CAN_1935',
#  'CAN_1936',
#  'CAN_1937',
#  'CAN_1938',
#  'CAN_1939',
#  'CAN_1940',
#  'CAN_1941',
#  'CAN_1942',
#  'CAN_1943',
#  'CAN_1944',
#  'CAN_1945',
#  'CAN_1946',
#  'CAN_1947',
#  'CAN_1948',
#  'CAN_1949',
#  'CAN_1950',
#  'CAN_1951',
#  'CAN_1952',
#  'CAN_1953',
#  'CAN_1954',
#  'CAN_1955',
#  'CAN_1956',
#  'CAN_1957',
#  'CAN_1958',
#  'CAN_1959',
#  'CAN_1960',
#  'CAN_1961',
#  'CAN_1962',
#  'CAN_1963',
#  'CAN_1964',
#  'CAN_1965',
#  'CAN_1966',
#  'CAN_1967',
#  'CAN_1968',
#  'CAN_1969',
#  'CAN_1970',
#  'CAN_1971',
#  'CAN_1972',
#  'CAN_1973',
#  'CAN_1974',
#  'CAN_1975',
#  'CAN_1976',
#  'CAN_1977',
#  'CAN_1978',
#  'CAN_1979',
#  'CAN_1980',
#  'CAN_1981',
#  'CAN_1982',
#  'CAN_1983',
#  'CAN_1984',
#  'CAN_1985',
#  'CAN_1986',
#  'CAN_1987',
#  'CAN_1988',
#  'CAN_1989',
#  'CAN_1990',
#  'CAN_1991',
#  'CAN_1992',
#  'CAN_1993',
#  'CAN_1994',
#  'CAN_1995',
#  'CAN_1996',
#  'CAN_1997',
#  'CAN_1998',
#  'CAN_1999',
#  'CAN_2000',
#  'CAN_2001',
#  'CAN_2002',
#  'CAN_2003',
#  'CAN_2004',
#  'CAN_2005',
#  'CAN_2006',
#  'CAN_2007',
#  'CAN_2008',
#  'CAN_2009',
#  'CAN_2010',
#  'HRV_1993',
#  'HRV_1994',
#  'HRV_1995',
#  'HRV_1996',
#  'HRV_1997',
#  'HRV_1998',
#  'HRV_1999',
#  'HRV_2000',
#  'HRV_2001',
#  'HRV_2002',
#  'HRV_2003',
#  'HRV_2004',
#  'HRV_2005',
#  'HRV_2006',
#  'HRV_2007',
#  'HRV_2008',
#  'HRV_2009',
#  'HRV_2010',
#  'HRV_2011',
#  'HRV_2012',
#  'HRV_2013',
#  'CZE_1975',
#  'CZE_1980',
#  'CZE_1981',
#  'CZE_1982',
#  'CZE_1983',
#  'CZE_1984',
#  'CZE_1985',
#  'CZE_1986',
#  'CZE_1987',
#  'CZE_1988',
#  'CZE_1989',
#  'CZE_1993',
#  'CZE_1994',
#  'CZE_1995',
#  'CZE_1996',
#  'CZE_1997',
#  'CZE_1998',
#  'CZE_1999',
#  'CZE_2000',
#  'CZE_2001',
#  'CZE_2002',
#  'CZE_2003',
#  'CZE_2004',
#  'CZE_2005',
#  'CZE_2006',
#  'CZE_2007',
#  'CZE_2008',
#  'CZE_2009',
#  'CZE_2010',
#  'CZE_2011',
#  'CZE_2012',
#  'CZE_2013',
#  'CZE_2014',
#  'OWID_CZS_1923',
#  'OWID_CZS_1924',
#  'OWID_CZS_1925',
#  'OWID_CZS_1926',
#  'OWID_CZS_1927',
#  'OWID_CZS_1928',
#  'OWID_CZS_1929',
#  'OWID_CZS_1930',
#  'OWID_CZS_1931',
#  'OWID_CZS_1932',
#  'OWID_CZS_1933',
#  'OWID_CZS_1934',
#  'OWID_CZS_1937',
#  'OWID_CZS_1948',
#  'OWID_CZS_1950',
#  'OWID_CZS_1953',
#  'OWID_CZS_1955',
#  'OWID_CZS_1960',
#  'OWID_CZS_1961',
#  'OWID_CZS_1962',
#  'OWID_CZS_1963',
#  'OWID_CZS_1964',
#  'OWID_CZS_1965',
#  'OWID_CZS_1966',
#  'OWID_CZS_1967',
#  'OWID_CZS_1968',
#  'OWID_CZS_1969',
#  'OWID_CZS_1970',
#  'OWID_CZS_1971',
#  'OWID_CZS_1972',
#  'OWID_CZS_1973',
#  'OWID_CZS_1974',
#  'OWID_CZS_1975',
#  'OWID_CZS_1976',
#  'OWID_CZS_1977',
#  'OWID_CZS_1978',
#  'OWID_CZS_1979',
#  'OWID_CZS_1980',
#  'OWID_CZS_1981',
#  'OWID_CZS_1982',
#  'OWID_CZS_1983',
#  'OWID_CZS_1984',
#  'OWID_CZS_1985',
#  'OWID_CZS_1986',
#  'OWID_CZS_1987',
#  'OWID_CZS_1988',
#  'OWID_CZS_1989',
#  'OWID_CZS_1990',
#  'OWID_CZS_1991',
#  'OWID_CZS_1992',
#  'DNK_1920',
#  'DNK_1921',
#  'DNK_1922',
#  'DNK_1923',
#  'DNK_1924',
#  'DNK_1925',
#  'DNK_1926',
#  'DNK_1927',
#  'DNK_1928',
#  'DNK_1929',
#  'DNK_1930',
#  'DNK_1931',
#  'DNK_1932',
#  'DNK_1933',
#  'DNK_1934',
#  'DNK_1935',
#  'DNK_1936',
#  'DNK_1937',
#  'DNK_1938',
#  'DNK_1939',
#  'DNK_1940',
#  'DNK_1941',
#  'DNK_1942',
#  'DNK_1943',
#  'DNK_1944',
#  'DNK_1945',
#  'DNK_1946',
#  'DNK_1947',
#  'DNK_1948',
#  'DNK_1949',
#  'DNK_1950',
#  'DNK_1951',
#  'DNK_1952',
#  'DNK_1953',
#  'DNK_1954',
#  'DNK_1955',
#  'DNK_1956',
#  'DNK_1957',
#  'DNK_1958',
#  'DNK_1959',
#  'DNK_1960',
#  'DNK_1961',
#  'DNK_1962',
#  'DNK_1963',
#  'DNK_1964',
#  'DNK_1965',
#  'DNK_1966',
#  'DNK_1967',
#  'DNK_1968',
#  'DNK_1969',
#  'DNK_1970',
#  'DNK_1971',
#  'DNK_1972',
#  'DNK_1973',
#  'DNK_1974',
#  'DNK_1975',
#  'DNK_1976',
#  'DNK_1977',
#  'DNK_1978',
#  'DNK_1979',
#  'DNK_1980',
#  'DNK_1981',
#  'DNK_1982',
#  'DNK_1983',
#  'DNK_1984',
#  'DNK_1985',
#  'DNK_1986',
#  'DNK_1987',
#  'DNK_1988',
#  'DNK_1989',
#  'DNK_1990',
#  'DNK_1991',
#  'DNK_1992',
#  'DNK_1993',
#  'DNK_1994',
#  'DNK_1995',
#  'DNK_1996',
#  'DNK_1997',
#  'DNK_1998',
#  'DNK_1999',
#  'DNK_2000',
#  'DNK_2001',
#  'DNK_2002',
#  'DNK_2003',
#  'DNK_2004',
#  'DNK_2005',
#  'DNK_2006',
#  'DNK_2007',
#  'DNK_2008',
#  'DNK_2009',
#  'DNK_2010',
#  'EST_1988',
#  'EST_1989',
#  'EST_1990',
#  'EST_1991',
#  'EST_1992',
#  'EST_1993',
#  'EST_1994',
#  'EST_1995',
#  'EST_1996',
#  'EST_1997',
#  'EST_1998',
#  'EST_1999',
#  'EST_2000',
#  'EST_2001',
#  'EST_2002',
#  'EST_2003',
#  'EST_2004',
#  'EST_2005',
#  'EST_2006',
#  'EST_2007',
#  'EST_2008',
#  'EST_2009',
#  'EST_2010',
#  'EST_2011',
#  'EST_2012',
#  'EST_2013',
#  'EST_2014',
#  'FIN_1920',
#  'FIN_1921',
#  'FIN_1922',
#  'FIN_1923',
#  'FIN_1924',
#  'FIN_1925',
#  'FIN_1926',
#  'FIN_1927',
#  'FIN_1928',
#  'FIN_1929',
#  'FIN_1930',
#  'FIN_1931',
#  'FIN_1932',
#  'FIN_1933',
#  'FIN_1934',
#  'FIN_1935',
#  'FIN_1936',
#  'FIN_1937',
#  'FIN_1938',
#  'FIN_1939',
#  'FIN_1940',
#  'FIN_1941',
#  'FIN_1942',
#  'FIN_1943',
#  'FIN_1944',
#  'FIN_1945',
#  'FIN_1946',
#  'FIN_1947',
#  'FIN_1948',
#  'FIN_1949',
#  'FIN_1950',
#  'FIN_1951',
#  'FIN_1952',
#  'FIN_1953',
#  'FIN_1954',
#  'FIN_1955',
#  'FIN_1956',
#  'FIN_1957',
#  'FIN_1958',
#  'FIN_1959',
#  'FIN_1960',
#  'FIN_1961',
#  'FIN_1962',
#  'FIN_1963',
#  'FIN_1964',
#  'FIN_1965',
#  'FIN_1966',
#  'FIN_1967',
#  'FIN_1968',
#  'FIN_1969',
#  'FIN_1970',
#  'FIN_1971',
#  'FIN_1972',
#  'FIN_1973',
#  'FIN_1974',
#  'FIN_1975',
#  'FIN_1976',
#  'FIN_1977',
#  'FIN_1978',
#  'FIN_1979',
#  'FIN_1980',
#  'FIN_1981',
#  'FIN_1982',
#  'FIN_1983',
#  'FIN_1984',
#  'FIN_1985',
#  'FIN_1986',
#  'FIN_1987',
#  'FIN_1988',
#  'FIN_1989',
#  'FIN_1990',
#  'FIN_1991',
#  'FIN_1992',
#  'FIN_1993',
#  'FIN_1994',
#  'FIN_1995',
#  'FIN_1996',
#  'FIN_1997',
#  'FIN_1998',
#  'FIN_1999',
#  'FIN_2000',
#  'FIN_2001',
#  'FIN_2002',
#  'FIN_2003',
#  'FIN_2004',
#  'FIN_2005',
#  'FIN_2006',
#  'FIN_2007',
#  'FIN_2008',
#  'FIN_2009',
#  'FRA_1875',
#  'FRA_1880',
#  'FRA_1885',
#  'FRA_1890',
#  'FRA_1895',
#  'FRA_1900',
#  'FRA_1901',
#  'FRA_1902',
#  'FRA_1903',
#  'FRA_1904',
#  'FRA_1905',
#  'FRA_1906',
#  'FRA_1907',
#  'FRA_1908',
#  'FRA_1909',
#  'FRA_1910',
#  'FRA_1913',
#  'FRA_1923',
#  'FRA_1924',
#  'FRA_1932',
#  'FRA_1933',
#  'FRA_1934',
#  'FRA_1935',
#  'FRA_1936',
#  'FRA_1937',
#  'FRA_1938',
#  'FRA_1939',
#  'FRA_1940',
#  'FRA_1941',
#  'FRA_1942',
#  'FRA_1943',
#  'FRA_1944',
#  'FRA_1945',
#  'FRA_1946',
#  'FRA_1947',
#  'FRA_1948',
#  'FRA_1949',
#  'FRA_1950',
#  'FRA_1951',
#  'FRA_1952',
#  'FRA_1953',
#  'FRA_1954',
#  'FRA_1955',
#  'FRA_1956',
#  'FRA_1957',
#  'FRA_1958',
#  'FRA_1959',
#  'FRA_1960',
#  'FRA_1961',
#  'FRA_1962',
#  'FRA_1963',
#  'FRA_1964',
#  'FRA_1965',
#  'FRA_1966',
#  'FRA_1967',
#  'FRA_1968',
#  'FRA_1969',
#  'FRA_1970',
#  'FRA_1971',
#  'FRA_1972',
#  'FRA_1973',
#  'FRA_1974',
#  'FRA_1975',
#  'FRA_1976',
#  'FRA_1977',
#  'FRA_1978',
#  'FRA_1979',
#  'FRA_1980',
#  'FRA_1981',
#  'FRA_1982',
#  'FRA_1983',
#  'FRA_1984',
#  'FRA_1985',
#  'FRA_1986',
#  'FRA_1987',
#  'FRA_1988',
#  'FRA_1989',
#  'FRA_1990',
#  'FRA_1991',
#  'FRA_1992',
#  'FRA_1993',
#  'FRA_1994',
#  'FRA_1995',
#  'FRA_1996',
#  'FRA_1997',
#  'FRA_1998',
#  'FRA_1999',
#  'FRA_2000',
#  'FRA_2001',
#  'FRA_2002',
#  'FRA_2003',
#  'FRA_2004',
#  'FRA_2005',
#  'FRA_2006',
#  'FRA_2007',
#  'FRA_2008',
#  'FRA_2009',
#  'FRA_2010',
#  'GEO_1988',
#  'GEO_1989',
#  'GEO_1990',
#  'GEO_1991',
#  'GEO_1992',
#  'GEO_1993',
#  'GEO_1994',
#  'GEO_1995',
#  'GEO_1996',
#  'GEO_1997',
#  'GEO_1998',
#  'GEO_1999',
#  'DEU_1906',
#  'DEU_1907',
#  'DEU_1908',
#  'DEU_1909',
#  'DEU_1910',
#  'DEU_1911',
#  'DEU_1912',
#  'DEU_1913',
#  'DEU_1925',
#  'DEU_1926',
#  'DEU_1927',
#  'DEU_1928',
#  'DEU_1929',
#  'DEU_1930',
#  'DEU_1931',
#  'DEU_1932',
#  'DEU_1933',
#  'DEU_1934',
#  'DEU_1935',
#  'DEU_1936',
#  'DEU_1937',
#  'DEU_1938',
#  'DEU_1950',
#  'DEU_1951',
#  'DEU_1952',
#  'DEU_1953',
#  'DEU_1954',
#  'DEU_1955',
#  'DEU_1956',
#  'DEU_1957',
#  'DEU_1958',
#  'DEU_1959',
#  'DEU_1960',
#  'DEU_1961',
#  'DEU_1962',
#  'DEU_1963',
#  'DEU_1964',
#  'DEU_1965',
#  'DEU_1966',
#  'DEU_1967',
#  'DEU_1968',
#  'DEU_1969',
#  'DEU_1970',
#  'DEU_1971',
#  'DEU_1972',
#  'DEU_1973',
#  'DEU_1974',
#  'DEU_1975',
#  'DEU_1976',
#  'DEU_1977',
#  'DEU_1978',
#  'DEU_1979',
#  'DEU_1980',
#  'DEU_1981',
#  'DEU_1982',
#  'DEU_1983',
#  'DEU_1984',
#  'DEU_1985',
#  'DEU_1986',
#  'DEU_1987',
#  'DEU_1988',
#  'DEU_1989',
#  'DEU_1991',
#  'DEU_1992',
#  'DEU_1993',
#  'DEU_1994',
#  'DEU_1995',
#  'DEU_1996',
#  'DEU_1997',
#  'DEU_1998',
#  'DEU_1999',
#  'DEU_2000',
#  'DEU_2001',
#  'DEU_2002',
#  'DEU_2003',
#  'DEU_2004',
#  'DEU_2005',
#  'DEU_2006',
#  'DEU_2007',
#  'DEU_2008',
#  'DEU_2009',
#  'DEU_2010',
#  'DEU_2011',
#  'DEU_2012',
#  'DEU_2013',
#  'DEU_2014',
#  'DEU_2015',
#  'GRC_1920',
#  'GRC_1921',
#  'GRC_1922',
#  'GRC_1923',
#  'GRC_1924',
#  'GRC_1925',
#  'GRC_1926',
#  'GRC_1927',
#  'GRC_1928',
#  'GRC_1929',
#  'GRC_1930',
#  'GRC_1931',
#  'GRC_1932',
#  'GRC_1933',
#  'GRC_1934',
#  'GRC_1935',
#  'GRC_1936',
#  'GRC_1937',
#  'GRC_1938',
#  'GRC_1939',
#  'GRC_1940',
#  'GRC_1941',
#  'GRC_1942',
#  'GRC_1943',
#  'GRC_1944',
#  'GRC_1945',
#  'GRC_1946',
#  'GRC_1947',
#  'GRC_1948',
#  'GRC_1949',
#  'GRC_1950',
#  'GRC_1951',
#  'GRC_1952',
#  'GRC_1953',
#  'GRC_1954',
#  'GRC_1955',
#  'GRC_1956',
#  'GRC_1957',
#  'GRC_1958',
#  'GRC_1959',
#  'GRC_1960',
#  'GRC_1961',
#  'GRC_1962',
#  'GRC_1963',
#  'GRC_1964',
#  ...]

# %%
# setting a new index for cigarettes_df
cigarettes_df['new_index'] = cigarettes_index
cigarettes_df
# Out:
#           Entity      Code  Year  \
# 0        Armenia       ARM  1988
# 1        Armenia       ARM  1989
# 2        Armenia       ARM  1990
# 3        Armenia       ARM  1991
# 4        Armenia       ARM  1992
# ...          ...       ...   ...
# 2762  Yugoslavia  OWID_YGS  1988
# 2763  Yugoslavia  OWID_YGS  1989
# 2764  Yugoslavia  OWID_YGS  1990
# 2765  Yugoslavia  OWID_YGS  1991
# 2766  Yugoslavia  OWID_YGS  1992
#
#       Sales of cigarettes per adult per day (International Smoking Statistics (2017))   \
# 0                                                  12.0
# 1                                                  11.6
# 2                                                  11.9
# 3                                                   9.3
# 4                                                   4.9
# ...                                                 ...
# 2762                                                8.9
# 2763                                                8.5
# 2764                                                8.5
# 2765                                                7.8
# 2766                                                6.7
#
#           new_index
# 0          ARM_1988
# 1          ARM_1989
# 2          ARM_1990
# 3          ARM_1991
# 4          ARM_1992
# ...             ...
# 2762  OWID_YGS_1988
# 2763  OWID_YGS_1989
# 2764  OWID_YGS_1990
# 2765  OWID_YGS_1991
# 2766  OWID_YGS_1992
#
# [2767 rows x 5 columns]

# %%
# merging dataframes

merged_df1 = pd.merge(left= co2_df, right= lungcancer_df, left_on='new_index', right_on='new_index')
merged_df1
# Out:
#      country_code  country_name  year          value new_index        Entity  \
# 0             ALB       Albania  1987    7444.010000  ALB_1987       Albania
# 1             ALB       Albania  1988    7326.666000  ALB_1988       Albania
# 2             ALB       Albania  1989    8984.150000  ALB_1989       Albania
# 3             ALB       Albania  1992    2220.000000  ALB_1992       Albania
# 4             ALB       Albania  1993    2060.000000  ALB_1993       Albania
# ...           ...           ...   ...            ...       ...           ...
# 4044          ZAF  South Africa  2014  447929.992676  ZAF_2014  South Africa
# 4045          ZAF  South Africa  2015  424809.997559  ZAF_2015  South Africa
# 4046          ZAF  South Africa  2016  425140.014648  ZAF_2016  South Africa
# 4047          ZAF  South Africa  2017  435649.993896  ZAF_2017  South Africa
# 4048          ZAF  South Africa  2018  434350.006104  ZAF_2018  South Africa
#
#      Code  Year  age-standardized_death_rate_per_100k_male  \
# 0     ALB  1987                                      38.99
# 1     ALB  1988                                      41.27
# 2     ALB  1989                                      36.56
# 3     ALB  1992                                      29.70
# 4     ALB  1993                                      27.44
# ...   ...   ...                                        ...
# 4044  ZAF  2014                                      22.80
# 4045  ZAF  2015                                      23.58
# 4046  ZAF  2016                                      25.15
# 4047  ZAF  2017                                      23.51
# 4048  ZAF  2018                                      22.86
#
#       age-standardized_death_rate_per_100k_female
# 0                                            5.95
# 1                                            6.97
# 2                                            4.42
# 3                                            5.68
# 4                                            5.41
# ...                                           ...
# 4044                                         8.45
# 4045                                         8.86
# 4046                                         9.43
# 4047                                         9.15
# 4048                                         8.90
#
# [4049 rows x 10 columns]

# %%
merged_df = pd.merge(left=merged_df1, right=cigarettes_df, left_on='new_index', right_on='new_index')

# %%
merged_df
# Out:
#      country_code   country_name  year         value new_index       Entity_x  \
# 0             ARM        Armenia  1990  1.985000e+04  ARM_1990        Armenia
# 1             ARM        Armenia  1991  2.069000e+04  ARM_1991        Armenia
# 2             ARM        Armenia  1992  1.090000e+04  ARM_1992        Armenia
# 3             ARM        Armenia  1993  5.040000e+03  ARM_1993        Armenia
# 4             ARM        Armenia  1994  2.740000e+03  ARM_1994        Armenia
# ...           ...            ...   ...           ...       ...            ...
# 1588          USA  United States  2010  5.392110e+06  USA_2010  United States
# 1589          USA  United States  2011  5.173600e+06  USA_2011  United States
# 1590          USA  United States  2012  4.956060e+06  USA_2012  United States
# 1591          USA  United States  2013  5.092100e+06  USA_2013  United States
# 1592          USA  United States  2014  5.107210e+06  USA_2014  United States
#
#      Code_x  Year_x  age-standardized_death_rate_per_100k_male  \
# 0       ARM    1990                                      51.36
# 1       ARM    1991                                      49.99
# 2       ARM    1992                                      45.04
# 3       ARM    1993                                      40.77
# 4       ARM    1994                                      36.68
# ...     ...     ...                                        ...
# 1588    USA    2010                                      40.85
# 1589    USA    2011                                      39.27
# 1590    USA    2012                                      38.15
# 1591    USA    2013                                      36.62
# 1592    USA    2014                                      35.31
#
#       age-standardized_death_rate_per_100k_female       Entity_y Code_y  \
# 0                                            7.40        Armenia    ARM
# 1                                            6.01        Armenia    ARM
# 2                                            7.44        Armenia    ARM
# 3                                            6.69        Armenia    ARM
# 4                                            5.89        Armenia    ARM
# ...                                           ...            ...    ...
# 1588                                        26.54  United States    USA
# 1589                                        25.81  United States    USA
# 1590                                        25.49  United States    USA
# 1591                                        24.83  United States    USA
# 1592                                        24.29  United States    USA
#
#       Year_y  \
# 0       1990
# 1       1991
# 2       1992
# 3       1993
# 4       1994
# ...      ...
# 1588    2010
# 1589    2011
# 1590    2012
# 1591    2013
# 1592    2014
#
#       Sales of cigarettes per adult per day (International Smoking Statistics (2017))
# 0                                                  11.9
# 1                                                   9.3
# 2                                                   4.9
# 3                                                   5.5
# 4                                                   5.7
# ...                                                 ...
# 1588                                                3.6
# 1589                                                3.5
# 1590                                                3.5
# 1591                                                3.3
# 1592                                                3.2
#
# [1593 rows x 14 columns]

# %%
merged_df = merged_df.drop(columns=['Entity_x', 'Code_x', 'Year_x', 'Entity_y', 'Code_y', 'Year_y'])

# %%
merged_df.rename(columns={'value': 'co2_emissions', 'new_index': 'merge_id'}, inplace=True)
merged_df
# Out:
#      country_code   country_name  year  co2_emissions  merge_id  \
# 0             ARM        Armenia  1990   1.985000e+04  ARM_1990
# 1             ARM        Armenia  1991   2.069000e+04  ARM_1991
# 2             ARM        Armenia  1992   1.090000e+04  ARM_1992
# 3             ARM        Armenia  1993   5.040000e+03  ARM_1993
# 4             ARM        Armenia  1994   2.740000e+03  ARM_1994
# ...           ...            ...   ...            ...       ...
# 1588          USA  United States  2010   5.392110e+06  USA_2010
# 1589          USA  United States  2011   5.173600e+06  USA_2011
# 1590          USA  United States  2012   4.956060e+06  USA_2012
# 1591          USA  United States  2013   5.092100e+06  USA_2013
# 1592          USA  United States  2014   5.107210e+06  USA_2014
#
#       age-standardized_death_rate_per_100k_male  \
# 0                                         51.36
# 1                                         49.99
# 2                                         45.04
# 3                                         40.77
# 4                                         36.68
# ...                                         ...
# 1588                                      40.85
# 1589                                      39.27
# 1590                                      38.15
# 1591                                      36.62
# 1592                                      35.31
#
#       age-standardized_death_rate_per_100k_female  \
# 0                                            7.40
# 1                                            6.01
# 2                                            7.44
# 3                                            6.69
# 4                                            5.89
# ...                                           ...
# 1588                                        26.54
# 1589                                        25.81
# 1590                                        25.49
# 1591                                        24.83
# 1592                                        24.29
#
#       Sales of cigarettes per adult per day (International Smoking Statistics (2017))
# 0                                                  11.9
# 1                                                   9.3
# 2                                                   4.9
# 3                                                   5.5
# 4                                                   5.7
# ...                                                 ...
# 1588                                                3.6
# 1589                                                3.5
# 1590                                                3.5
# 1591                                                3.3
# 1592                                                3.2
#
# [1593 rows x 8 columns]

# %%
print(merged_df['country_code'].nunique())
print(merged_df['country_code'].value_counts())
# Out:
# 42
# JPN    56
# ISL    56
# USA    55
# GBR    55
# ROU    53
# NLD    53
# HUN    53
# NOR    52
# GRC    52
# IRL    52
# BEL    52
# FRA    51
# DNK    51
# ITA    51
# CAN    51
# POL    51
# ESP    51
# CHE    50
# FIN    50
# AUS    50
# PRT    50
# NZL    50
# BGR    49
# SWE    47
# AUT    45
# ISR    40
# LTU    25
# LVA    25
# DEU    25
# EST    25
# CZE    22
# HRV    21
# SVN    21
# SVK    20
# RUS    17
# KAZ    11
# MDA    10
# AZE     9
# KGZ     9
# BLR     9
# GEO     9
# ARM     9
# Name: country_code, dtype: int64

# %%
merged_df.to_csv('Resources/merged_data.csv', index=False)

# %%
import csv
import json
 
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['merge_id']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'Resources/merged_data.csv'
jsonFilePath = r'Resources/merged_data.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
countries = merged_df['country_name'].unique()
countries
merged_df.columns
# Out:
# Index(['country_code', 'country_name', 'year', 'co2_emissions', 'merge_id',
#        'age-standardized_death_rate_per_100k_male',
#        'age-standardized_death_rate_per_100k_female',
#        'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) '],
#       dtype='object')

# %%
nodes = merged_df[['country_name']].melt(var_name='country', value_name='id').drop_duplicates().to_dict('r')
# nodes = merged_df[['country_name']].melt().drop_duplicates().to_dict('r')
nodes = list(merged_df[['country_name']])


nodes = list(merged_df.country_name.unique())
nodes
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   """Entry point for launching an IPython kernel.
# ['Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belgium',
#  'Bulgaria',
#  'Belarus',
#  'Canada',
#  'Switzerland',
#  'Czechia',
#  'Germany',
#  'Denmark',
#  'Spain',
#  'Estonia',
#  'Finland',
#  'France',
#  'United Kingdom',
#  'Georgia',
#  'Greece',
#  'Croatia',
#  'Hungary',
#  'Ireland',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kazakhstan',
#  'Kyrgyz Republic',
#  'Lithuania',
#  'Latvia',
#  'Moldova',
#  'Netherlands',
#  'Norway',
#  'New Zealand',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russian Federation',
#  'Slovak Republic',
#  'Slovenia',
#  'Sweden',
#  'United States']

# %%
data = {'country': nodes, 'metadata': links}
data
# Out:
# {'country': ['Armenia',
#   'Australia',
#   'Austria',
#   'Azerbaijan',
#   'Belgium',
#   'Bulgaria',
#   'Belarus',
#   'Canada',
#   'Switzerland',
#   'Czechia',
#   'Germany',
#   'Denmark',
#   'Spain',
#   'Estonia',
#   'Finland',
#   'France',
#   'United Kingdom',
#   'Georgia',
#   'Greece',
#   'Croatia',
#   'Hungary',
#   'Ireland',
#   'Iceland',
#   'Israel',
#   'Italy',
#   'Japan',
#   'Kazakhstan',
#   'Kyrgyz Republic',
#   'Lithuania',
#   'Latvia',
#   'Moldova',
#   'Netherlands',
#   'Norway',
#   'New Zealand',
#   'Poland',
#   'Portugal',
#   'Romania',
#   'Russian Federation',
#   'Slovak Republic',
#   'Slovenia',
#   'Sweden',
#   'United States'],
#  'metadata': [{'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1990,
#    'co2_emissions': 19850.0,
#    'merge_id': 'ARM_1990',
#    'age-standardized_death_rate_per_100k_male': 51.36,
#    'age-standardized_death_rate_per_100k_female': 7.4,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 11.89999961853027},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1991,
#    'co2_emissions': 20690.0,
#    'merge_id': 'ARM_1991',
#    'age-standardized_death_rate_per_100k_male': 49.99,
#    'age-standardized_death_rate_per_100k_female': 6.01,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.300000190734863},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1992,
#    'co2_emissions': 10900.0,
#    'merge_id': 'ARM_1992',
#    'age-standardized_death_rate_per_100k_male': 45.04,
#    'age-standardized_death_rate_per_100k_female': 7.44,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.900000095367432},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1993,
#    'co2_emissions': 5040.0,
#    'merge_id': 'ARM_1993',
#    'age-standardized_death_rate_per_100k_male': 40.77,
#    'age-standardized_death_rate_per_100k_female': 6.69,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.5},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1994,
#    'co2_emissions': 2740.0,
#    'merge_id': 'ARM_1994',
#    'age-standardized_death_rate_per_100k_male': 36.68,
#    'age-standardized_death_rate_per_100k_female': 5.89,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1995,
#    'co2_emissions': 3510.0,
#    'merge_id': 'ARM_1995',
#    'age-standardized_death_rate_per_100k_male': 37.88,
#    'age-standardized_death_rate_per_100k_female': 4.41,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1996,
#    'co2_emissions': 2580.0,
#    'merge_id': 'ARM_1996',
#    'age-standardized_death_rate_per_100k_male': 38.72,
#    'age-standardized_death_rate_per_100k_female': 4.45,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1997,
#    'co2_emissions': 3340.0,
#    'merge_id': 'ARM_1997',
#    'age-standardized_death_rate_per_100k_male': 40.69,
#    'age-standardized_death_rate_per_100k_female': 4.7,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ARM',
#    'country_name': 'Armenia',
#    'year': 1998,
#    'co2_emissions': 3470.0,
#    'merge_id': 'ARM_1998',
#    'age-standardized_death_rate_per_100k_male': 38.05,
#    'age-standardized_death_rate_per_100k_female': 5.43,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1960,
#    'co2_emissions': 88202.351,
#    'merge_id': 'AUS_1960',
#    'age-standardized_death_rate_per_100k_male': 29.56,
#    'age-standardized_death_rate_per_100k_female': 3.87,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.100000381469728},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1961,
#    'co2_emissions': 90589.568,
#    'merge_id': 'AUS_1961',
#    'age-standardized_death_rate_per_100k_male': 32.45,
#    'age-standardized_death_rate_per_100k_female': 4.0,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.0},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1962,
#    'co2_emissions': 94912.961,
#    'merge_id': 'AUS_1962',
#    'age-standardized_death_rate_per_100k_male': 34.74,
#    'age-standardized_death_rate_per_100k_female': 4.33,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.800000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1963,
#    'co2_emissions': 101029.517,
#    'merge_id': 'AUS_1963',
#    'age-standardized_death_rate_per_100k_male': 35.97,
#    'age-standardized_death_rate_per_100k_female': 4.39,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.699999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1964,
#    'co2_emissions': 108979.573,
#    'merge_id': 'AUS_1964',
#    'age-standardized_death_rate_per_100k_male': 38.51,
#    'age-standardized_death_rate_per_100k_female': 4.94,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.800000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1965,
#    'co2_emissions': 120966.996,
#    'merge_id': 'AUS_1965',
#    'age-standardized_death_rate_per_100k_male': 39.41,
#    'age-standardized_death_rate_per_100k_female': 4.74,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.699999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1966,
#    'co2_emissions': 120332.605,
#    'merge_id': 'AUS_1966',
#    'age-standardized_death_rate_per_100k_male': 41.74,
#    'age-standardized_death_rate_per_100k_female': 5.02,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.899999618530273},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1967,
#    'co2_emissions': 129265.417,
#    'merge_id': 'AUS_1967',
#    'age-standardized_death_rate_per_100k_male': 43.59,
#    'age-standardized_death_rate_per_100k_female': 5.74,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.5},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1968,
#    'co2_emissions': 134622.904,
#    'merge_id': 'AUS_1968',
#    'age-standardized_death_rate_per_100k_male': 45.0,
#    'age-standardized_death_rate_per_100k_female': 5.74,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.800000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1969,
#    'co2_emissions': 142257.598,
#    'merge_id': 'AUS_1969',
#    'age-standardized_death_rate_per_100k_male': 46.75,
#    'age-standardized_death_rate_per_100k_female': 5.66,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.899999618530273},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1970,
#    'co2_emissions': 147618.752,
#    'merge_id': 'AUS_1970',
#    'age-standardized_death_rate_per_100k_male': 47.79,
#    'age-standardized_death_rate_per_100k_female': 7.18,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.100000381469728},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1971,
#    'co2_emissions': 152774.554,
#    'merge_id': 'AUS_1971',
#    'age-standardized_death_rate_per_100k_male': 49.28,
#    'age-standardized_death_rate_per_100k_female': 7.53,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.899999618530273},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1972,
#    'co2_emissions': 157486.649,
#    'merge_id': 'AUS_1972',
#    'age-standardized_death_rate_per_100k_male': 50.06,
#    'age-standardized_death_rate_per_100k_female': 7.13,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.199999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1973,
#    'co2_emissions': 170992.21,
#    'merge_id': 'AUS_1973',
#    'age-standardized_death_rate_per_100k_male': 51.24,
#    'age-standardized_death_rate_per_100k_female': 7.82,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.399999618530272},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1974,
#    'co2_emissions': 172356.334,
#    'merge_id': 'AUS_1974',
#    'age-standardized_death_rate_per_100k_male': 53.83,
#    'age-standardized_death_rate_per_100k_female': 7.69,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 10.0},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1975,
#    'co2_emissions': 175883.988,
#    'merge_id': 'AUS_1975',
#    'age-standardized_death_rate_per_100k_male': 52.37,
#    'age-standardized_death_rate_per_100k_female': 7.85,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.699999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1976,
#    'co2_emissions': 174244.839,
#    'merge_id': 'AUS_1976',
#    'age-standardized_death_rate_per_100k_male': 53.83,
#    'age-standardized_death_rate_per_100k_female': 8.58,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.100000381469728},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1977,
#    'co2_emissions': 187787.07,
#    'merge_id': 'AUS_1977',
#    'age-standardized_death_rate_per_100k_male': 52.72,
#    'age-standardized_death_rate_per_100k_female': 9.83,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.800000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1978,
#    'co2_emissions': 202015.03,
#    'merge_id': 'AUS_1978',
#    'age-standardized_death_rate_per_100k_male': 53.22,
#    'age-standardized_death_rate_per_100k_female': 9.97,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.600000381469728},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1979,
#    'co2_emissions': 205069.641,
#    'merge_id': 'AUS_1979',
#    'age-standardized_death_rate_per_100k_male': 53.81,
#    'age-standardized_death_rate_per_100k_female': 10.3,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.399999618530272},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1980,
#    'co2_emissions': 220746.066,
#    'merge_id': 'AUS_1980',
#    'age-standardized_death_rate_per_100k_male': 56.21,
#    'age-standardized_death_rate_per_100k_female': 10.8,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.699999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1981,
#    'co2_emissions': 230360.94,
#    'merge_id': 'AUS_1981',
#    'age-standardized_death_rate_per_100k_male': 55.47,
#    'age-standardized_death_rate_per_100k_female': 10.46,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 9.300000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1982,
#    'co2_emissions': 234119.615,
#    'merge_id': 'AUS_1982',
#    'age-standardized_death_rate_per_100k_male': 55.42,
#    'age-standardized_death_rate_per_100k_female': 11.55,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.899999618530273},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1983,
#    'co2_emissions': 225003.453,
#    'merge_id': 'AUS_1983',
#    'age-standardized_death_rate_per_100k_male': 54.51,
#    'age-standardized_death_rate_per_100k_female': 12.47,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.399999618530273},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1984,
#    'co2_emissions': 236594.84,
#    'merge_id': 'AUS_1984',
#    'age-standardized_death_rate_per_100k_male': 54.62,
#    'age-standardized_death_rate_per_100k_female': 12.4,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.199999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1985,
#    'co2_emissions': 241229.928,
#    'merge_id': 'AUS_1985',
#    'age-standardized_death_rate_per_100k_male': 53.78,
#    'age-standardized_death_rate_per_100k_female': 12.65,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.100000381469727},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1986,
#    'co2_emissions': 239964.813,
#    'merge_id': 'AUS_1986',
#    'age-standardized_death_rate_per_100k_male': 51.02,
#    'age-standardized_death_rate_per_100k_female': 13.17,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.100000381469727},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1987,
#    'co2_emissions': 256106.947,
#    'merge_id': 'AUS_1987',
#    'age-standardized_death_rate_per_100k_male': 51.36,
#    'age-standardized_death_rate_per_100k_female': 12.54,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1988,
#    'co2_emissions': 261145.405,
#    'merge_id': 'AUS_1988',
#    'age-standardized_death_rate_per_100k_male': 51.19,
#    'age-standardized_death_rate_per_100k_female': 14.1,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1989,
#    'co2_emissions': 277771.583,
#    'merge_id': 'AUS_1989',
#    'age-standardized_death_rate_per_100k_male': 51.27,
#    'age-standardized_death_rate_per_100k_female': 14.49,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1990,
#    'co2_emissions': 263630.0,
#    'merge_id': 'AUS_1990',
#    'age-standardized_death_rate_per_100k_male': 47.27,
#    'age-standardized_death_rate_per_100k_female': 14.06,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1991,
#    'co2_emissions': 264760.0,
#    'merge_id': 'AUS_1991',
#    'age-standardized_death_rate_per_100k_male': 46.67,
#    'age-standardized_death_rate_per_100k_female': 15.03,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1992,
#    'co2_emissions': 268400.0,
#    'merge_id': 'AUS_1992',
#    'age-standardized_death_rate_per_100k_male': 46.68,
#    'age-standardized_death_rate_per_100k_female': 14.37,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1993,
#    'co2_emissions': 273050.0,
#    'merge_id': 'AUS_1993',
#    'age-standardized_death_rate_per_100k_male': 44.42,
#    'age-standardized_death_rate_per_100k_female': 14.97,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1994,
#    'co2_emissions': 280180.0,
#    'merge_id': 'AUS_1994',
#    'age-standardized_death_rate_per_100k_male': 46.23,
#    'age-standardized_death_rate_per_100k_female': 15.3,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.400000095367432},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1995,
#    'co2_emissions': 290180.0,
#    'merge_id': 'AUS_1995',
#    'age-standardized_death_rate_per_100k_male': 43.14,
#    'age-standardized_death_rate_per_100k_female': 15.36,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.300000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1996,
#    'co2_emissions': 300810.0,
#    'merge_id': 'AUS_1996',
#    'age-standardized_death_rate_per_100k_male': 42.99,
#    'age-standardized_death_rate_per_100k_female': 15.54,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1997,
#    'co2_emissions': 307850.0,
#    'merge_id': 'AUS_1997',
#    'age-standardized_death_rate_per_100k_male': 40.69,
#    'age-standardized_death_rate_per_100k_female': 15.43,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1998,
#    'co2_emissions': 328620.0,
#    'merge_id': 'AUS_1998',
#    'age-standardized_death_rate_per_100k_male': 40.3,
#    'age-standardized_death_rate_per_100k_female': 14.88,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.400000095367432},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 1999,
#    'co2_emissions': 333710.0,
#    'merge_id': 'AUS_1999',
#    'age-standardized_death_rate_per_100k_male': 38.52,
#    'age-standardized_death_rate_per_100k_female': 14.9,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2000,
#    'co2_emissions': 339450.0,
#    'merge_id': 'AUS_2000',
#    'age-standardized_death_rate_per_100k_male': 36.98,
#    'age-standardized_death_rate_per_100k_female': 15.79,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.900000095367432},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2001,
#    'co2_emissions': 345640.0,
#    'merge_id': 'AUS_2001',
#    'age-standardized_death_rate_per_100k_male': 36.33,
#    'age-standardized_death_rate_per_100k_female': 15.88,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.5},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2002,
#    'co2_emissions': 353369.995117188,
#    'merge_id': 'AUS_2002',
#    'age-standardized_death_rate_per_100k_male': 35.51,
#    'age-standardized_death_rate_per_100k_female': 16.34,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.300000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2003,
#    'co2_emissions': 352579.986572266,
#    'merge_id': 'AUS_2003',
#    'age-standardized_death_rate_per_100k_male': 33.0,
#    'age-standardized_death_rate_per_100k_female': 15.52,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.5},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2004,
#    'co2_emissions': 365809.997558594,
#    'merge_id': 'AUS_2004',
#    'age-standardized_death_rate_per_100k_male': 33.92,
#    'age-standardized_death_rate_per_100k_female': 15.49,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.300000190734863},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2006,
#    'co2_emissions': 375489.990234375,
#    'merge_id': 'AUS_2006',
#    'age-standardized_death_rate_per_100k_male': 32.46,
#    'age-standardized_death_rate_per_100k_female': 16.22,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.099999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2007,
#    'co2_emissions': 385750.0,
#    'merge_id': 'AUS_2007',
#    'age-standardized_death_rate_per_100k_male': 30.96,
#    'age-standardized_death_rate_per_100k_female': 16.6,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.099999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2008,
#    'co2_emissions': 388940.002441406,
#    'merge_id': 'AUS_2008',
#    'age-standardized_death_rate_per_100k_male': 31.88,
#    'age-standardized_death_rate_per_100k_female': 16.12,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.199999809265137},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2009,
#    'co2_emissions': 395290.008544922,
#    'merge_id': 'AUS_2009',
#    'age-standardized_death_rate_per_100k_male': 29.32,
#    'age-standardized_death_rate_per_100k_female': 16.36,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.099999904632568},
#   {'country_code': 'AUS',
#    'country_name': 'Australia',
#    'year': 2010,
#    'co2_emissions': 387540.008544922,
#    'merge_id': 'AUS_2010',
#    'age-standardized_death_rate_per_100k_male': 29.39,
#    'age-standardized_death_rate_per_100k_female': 16.61,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1960,
#    'co2_emissions': 30821.135,
#    'merge_id': 'AUT_1960',
#    'age-standardized_death_rate_per_100k_male': 53.61,
#    'age-standardized_death_rate_per_100k_female': 5.97,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.800000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1961,
#    'co2_emissions': 31862.563,
#    'merge_id': 'AUT_1961',
#    'age-standardized_death_rate_per_100k_male': 55.34,
#    'age-standardized_death_rate_per_100k_female': 6.39,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.699999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1962,
#    'co2_emissions': 33905.082,
#    'merge_id': 'AUT_1962',
#    'age-standardized_death_rate_per_100k_male': 53.28,
#    'age-standardized_death_rate_per_100k_female': 6.9,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.900000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1963,
#    'co2_emissions': 36992.696,
#    'merge_id': 'AUT_1963',
#    'age-standardized_death_rate_per_100k_male': 56.35,
#    'age-standardized_death_rate_per_100k_female': 6.75,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1964,
#    'co2_emissions': 38943.54,
#    'merge_id': 'AUT_1964',
#    'age-standardized_death_rate_per_100k_male': 53.35,
#    'age-standardized_death_rate_per_100k_female': 6.49,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.199999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1965,
#    'co2_emissions': 38188.138,
#    'merge_id': 'AUT_1965',
#    'age-standardized_death_rate_per_100k_male': 57.35,
#    'age-standardized_death_rate_per_100k_female': 6.58,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.400000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1966,
#    'co2_emissions': 39258.902,
#    'merge_id': 'AUT_1966',
#    'age-standardized_death_rate_per_100k_male': 56.58,
#    'age-standardized_death_rate_per_100k_female': 7.0,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.800000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1967,
#    'co2_emissions': 39966.633,
#    'merge_id': 'AUT_1967',
#    'age-standardized_death_rate_per_100k_male': 56.44,
#    'age-standardized_death_rate_per_100k_female': 6.92,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.900000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1968,
#    'co2_emissions': 42350.183,
#    'merge_id': 'AUT_1968',
#    'age-standardized_death_rate_per_100k_male': 58.89,
#    'age-standardized_death_rate_per_100k_female': 7.27,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1969,
#    'co2_emissions': 44693.396,
#    'merge_id': 'AUT_1969',
#    'age-standardized_death_rate_per_100k_male': 57.28,
#    'age-standardized_death_rate_per_100k_female': 7.12,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.199999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1970,
#    'co2_emissions': 50692.608,
#    'merge_id': 'AUT_1970',
#    'age-standardized_death_rate_per_100k_male': 56.04,
#    'age-standardized_death_rate_per_100k_female': 6.51,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.5},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1971,
#    'co2_emissions': 52155.741,
#    'merge_id': 'AUT_1971',
#    'age-standardized_death_rate_per_100k_male': 56.14,
#    'age-standardized_death_rate_per_100k_female': 7.42,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.599999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1972,
#    'co2_emissions': 56193.108,
#    'merge_id': 'AUT_1972',
#    'age-standardized_death_rate_per_100k_male': 57.6,
#    'age-standardized_death_rate_per_100k_female': 7.17,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.5},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1973,
#    'co2_emissions': 60164.469,
#    'merge_id': 'AUT_1973',
#    'age-standardized_death_rate_per_100k_male': 58.76,
#    'age-standardized_death_rate_per_100k_female': 7.41,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1974,
#    'co2_emissions': 57469.224,
#    'merge_id': 'AUT_1974',
#    'age-standardized_death_rate_per_100k_male': 57.33,
#    'age-standardized_death_rate_per_100k_female': 7.93,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.900000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1975,
#    'co2_emissions': 54392.611,
#    'merge_id': 'AUT_1975',
#    'age-standardized_death_rate_per_100k_male': 57.71,
#    'age-standardized_death_rate_per_100k_female': 7.65,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.599999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1976,
#    'co2_emissions': 58415.31,
#    'merge_id': 'AUT_1976',
#    'age-standardized_death_rate_per_100k_male': 57.28,
#    'age-standardized_death_rate_per_100k_female': 7.43,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.800000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1977,
#    'co2_emissions': 56218.777,
#    'merge_id': 'AUT_1977',
#    'age-standardized_death_rate_per_100k_male': 57.9,
#    'age-standardized_death_rate_per_100k_female': 7.67,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.900000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1978,
#    'co2_emissions': 57483.892,
#    'merge_id': 'AUT_1978',
#    'age-standardized_death_rate_per_100k_male': 56.27,
#    'age-standardized_death_rate_per_100k_female': 8.01,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1979,
#    'co2_emissions': 61594.599,
#    'merge_id': 'AUT_1979',
#    'age-standardized_death_rate_per_100k_male': 58.39,
#    'age-standardized_death_rate_per_100k_female': 8.08,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.199999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1980,
#    'co2_emissions': 52306.088,
#    'merge_id': 'AUT_1980',
#    'age-standardized_death_rate_per_100k_male': 57.32,
#    'age-standardized_death_rate_per_100k_female': 8.35,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.099999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1981,
#    'co2_emissions': 56130.769,
#    'merge_id': 'AUT_1981',
#    'age-standardized_death_rate_per_100k_male': 55.77,
#    'age-standardized_death_rate_per_100k_female': 8.42,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.099999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1982,
#    'co2_emissions': 53868.23,
#    'merge_id': 'AUT_1982',
#    'age-standardized_death_rate_per_100k_male': 54.28,
#    'age-standardized_death_rate_per_100k_female': 9.3,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1983,
#    'co2_emissions': 51983.392,
#    'merge_id': 'AUT_1983',
#    'age-standardized_death_rate_per_100k_male': 55.5,
#    'age-standardized_death_rate_per_100k_female': 8.97,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.199999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1984,
#    'co2_emissions': 54550.292,
#    'merge_id': 'AUT_1984',
#    'age-standardized_death_rate_per_100k_male': 57.49,
#    'age-standardized_death_rate_per_100k_female': 10.1,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1985,
#    'co2_emissions': 54700.639,
#    'merge_id': 'AUT_1985',
#    'age-standardized_death_rate_per_100k_male': 54.35,
#    'age-standardized_death_rate_per_100k_female': 9.18,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1986,
#    'co2_emissions': 54080.916,
#    'merge_id': 'AUT_1986',
#    'age-standardized_death_rate_per_100k_male': 53.53,
#    'age-standardized_death_rate_per_100k_female': 9.14,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1987,
#    'co2_emissions': 57744.249,
#    'merge_id': 'AUT_1987',
#    'age-standardized_death_rate_per_100k_male': 53.12,
#    'age-standardized_death_rate_per_100k_female': 10.23,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.800000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1988,
#    'co2_emissions': 53340.182,
#    'merge_id': 'AUT_1988',
#    'age-standardized_death_rate_per_100k_male': 52.29,
#    'age-standardized_death_rate_per_100k_female': 10.71,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.400000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1989,
#    'co2_emissions': 54117.586,
#    'merge_id': 'AUT_1989',
#    'age-standardized_death_rate_per_100k_male': 52.14,
#    'age-standardized_death_rate_per_100k_female': 9.75,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.199999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1990,
#    'co2_emissions': 58270.0,
#    'merge_id': 'AUT_1990',
#    'age-standardized_death_rate_per_100k_male': 51.95,
#    'age-standardized_death_rate_per_100k_female': 9.98,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.300000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1991,
#    'co2_emissions': 62420.0,
#    'merge_id': 'AUT_1991',
#    'age-standardized_death_rate_per_100k_male': 52.22,
#    'age-standardized_death_rate_per_100k_female': 10.97,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.400000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1992,
#    'co2_emissions': 57660.0,
#    'merge_id': 'AUT_1992',
#    'age-standardized_death_rate_per_100k_male': 49.73,
#    'age-standardized_death_rate_per_100k_female': 10.62,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.099999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1993,
#    'co2_emissions': 57800.0,
#    'merge_id': 'AUT_1993',
#    'age-standardized_death_rate_per_100k_male': 51.76,
#    'age-standardized_death_rate_per_100k_female': 10.97,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.800000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1994,
#    'co2_emissions': 58280.0,
#    'merge_id': 'AUT_1994',
#    'age-standardized_death_rate_per_100k_male': 47.64,
#    'age-standardized_death_rate_per_100k_female': 11.68,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.900000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1995,
#    'co2_emissions': 61180.0,
#    'merge_id': 'AUT_1995',
#    'age-standardized_death_rate_per_100k_male': 46.88,
#    'age-standardized_death_rate_per_100k_female': 11.02,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1996,
#    'co2_emissions': 64900.0,
#    'merge_id': 'AUT_1996',
#    'age-standardized_death_rate_per_100k_male': 47.1,
#    'age-standardized_death_rate_per_100k_female': 11.75,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.400000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1997,
#    'co2_emissions': 64220.0,
#    'merge_id': 'AUT_1997',
#    'age-standardized_death_rate_per_100k_male': 45.47,
#    'age-standardized_death_rate_per_100k_female': 12.35,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1998,
#    'co2_emissions': 64670.0,
#    'merge_id': 'AUT_1998',
#    'age-standardized_death_rate_per_100k_male': 46.04,
#    'age-standardized_death_rate_per_100k_female': 12.28,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.400000095367432},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 1999,
#    'co2_emissions': 63050.0,
#    'merge_id': 'AUT_1999',
#    'age-standardized_death_rate_per_100k_male': 43.22,
#    'age-standardized_death_rate_per_100k_female': 12.47,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.599999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 2000,
#    'co2_emissions': 63530.0,
#    'merge_id': 'AUT_2000',
#    'age-standardized_death_rate_per_100k_male': 42.13,
#    'age-standardized_death_rate_per_100k_female': 13.1,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.5},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 2001,
#    'co2_emissions': 67910.0,
#    'merge_id': 'AUT_2001',
#    'age-standardized_death_rate_per_100k_male': 40.82,
#    'age-standardized_death_rate_per_100k_female': 12.12,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.300000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 2002,
#    'co2_emissions': 69370.002746582,
#    'merge_id': 'AUT_2002',
#    'age-standardized_death_rate_per_100k_male': 42.02,
#    'age-standardized_death_rate_per_100k_female': 13.41,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.800000190734863},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 2003,
#    'co2_emissions': 74459.9990844727,
#    'merge_id': 'AUT_2003',
#    'age-standardized_death_rate_per_100k_male': 40.04,
#    'age-standardized_death_rate_per_100k_female': 12.74,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.599999904632568},
#   {'country_code': 'AUT',
#    'country_name': 'Austria',
#    'year': 2004,
#    'co2_emissions': 75800.0030517578,
#    'merge_id': 'AUT_2004',
#    'age-standardized_death_rate_per_100k_male': 39.06,
#    'age-standardized_death_rate_per_100k_female': 13.67,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.599999904632568},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1990,
#    'co2_emissions': 53480.0,
#    'merge_id': 'AZE_1990',
#    'age-standardized_death_rate_per_100k_male': 28.79,
#    'age-standardized_death_rate_per_100k_female': 4.76,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.400000095367432},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1991,
#    'co2_emissions': 52060.0,
#    'merge_id': 'AZE_1991',
#    'age-standardized_death_rate_per_100k_male': 30.37,
#    'age-standardized_death_rate_per_100k_female': 5.14,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.199999809265137},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1992,
#    'co2_emissions': 63610.0,
#    'merge_id': 'AZE_1992',
#    'age-standardized_death_rate_per_100k_male': 30.84,
#    'age-standardized_death_rate_per_100k_female': 5.19,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 3.799999952316284},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1993,
#    'co2_emissions': 48050.0,
#    'merge_id': 'AZE_1993',
#    'age-standardized_death_rate_per_100k_male': 28.03,
#    'age-standardized_death_rate_per_100k_female': 4.59,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 1.100000023841858},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1994,
#    'co2_emissions': 33520.0,
#    'merge_id': 'AZE_1994',
#    'age-standardized_death_rate_per_100k_male': 24.07,
#    'age-standardized_death_rate_per_100k_female': 4.81,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 3.299999952316284},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1995,
#    'co2_emissions': 32470.0,
#    'merge_id': 'AZE_1995',
#    'age-standardized_death_rate_per_100k_male': 23.15,
#    'age-standardized_death_rate_per_100k_female': 3.42,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 3.299999952316284},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1996,
#    'co2_emissions': 27190.0,
#    'merge_id': 'AZE_1996',
#    'age-standardized_death_rate_per_100k_male': 24.36,
#    'age-standardized_death_rate_per_100k_female': 3.88,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 3.299999952316284},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1997,
#    'co2_emissions': 26490.0,
#    'merge_id': 'AZE_1997',
#    'age-standardized_death_rate_per_100k_male': 25.39,
#    'age-standardized_death_rate_per_100k_female': 4.2,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 3.400000095367432},
#   {'country_code': 'AZE',
#    'country_name': 'Azerbaijan',
#    'year': 1998,
#    'co2_emissions': 26490.0,
#    'merge_id': 'AZE_1998',
#    'age-standardized_death_rate_per_100k_male': 22.37,
#    'age-standardized_death_rate_per_100k_female': 3.74,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 3.200000047683716},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1960,
#    'co2_emissions': 91000.272,
#    'merge_id': 'BEL_1960',
#    'age-standardized_death_rate_per_100k_male': 41.16,
#    'age-standardized_death_rate_per_100k_female': 4.28,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1961,
#    'co2_emissions': 92793.435,
#    'merge_id': 'BEL_1961',
#    'age-standardized_death_rate_per_100k_male': 43.57,
#    'age-standardized_death_rate_per_100k_female': 4.71,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1962,
#    'co2_emissions': 98117.919,
#    'merge_id': 'BEL_1962',
#    'age-standardized_death_rate_per_100k_male': 45.63,
#    'age-standardized_death_rate_per_100k_female': 5.03,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.400000095367432},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1963,
#    'co2_emissions': 105781.949,
#    'merge_id': 'BEL_1963',
#    'age-standardized_death_rate_per_100k_male': 48.19,
#    'age-standardized_death_rate_per_100k_female': 4.69,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.400000095367432},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1964,
#    'co2_emissions': 103662.423,
#    'merge_id': 'BEL_1964',
#    'age-standardized_death_rate_per_100k_male': 49.9,
#    'age-standardized_death_rate_per_100k_female': 5.22,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.400000095367432},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1965,
#    'co2_emissions': 105440.918,
#    'merge_id': 'BEL_1965',
#    'age-standardized_death_rate_per_100k_male': 54.72,
#    'age-standardized_death_rate_per_100k_female': 5.01,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.800000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1966,
#    'co2_emissions': 105206.23,
#    'merge_id': 'BEL_1966',
#    'age-standardized_death_rate_per_100k_male': 54.65,
#    'age-standardized_death_rate_per_100k_female': 4.6,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.0},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1967,
#    'co2_emissions': 107472.436,
#    'merge_id': 'BEL_1967',
#    'age-standardized_death_rate_per_100k_male': 57.11,
#    'age-standardized_death_rate_per_100k_female': 5.38,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.399999618530273},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1968,
#    'co2_emissions': 118557.777,
#    'merge_id': 'BEL_1968',
#    'age-standardized_death_rate_per_100k_male': 59.23,
#    'age-standardized_death_rate_per_100k_female': 5.14,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.100000381469727},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1969,
#    'co2_emissions': 123618.237,
#    'merge_id': 'BEL_1969',
#    'age-standardized_death_rate_per_100k_male': 60.38,
#    'age-standardized_death_rate_per_100k_female': 5.19,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.199999809265137},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1970,
#    'co2_emissions': 125620.419,
#    'merge_id': 'BEL_1970',
#    'age-standardized_death_rate_per_100k_male': 64.17,
#    'age-standardized_death_rate_per_100k_female': 4.94,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.399999618530273},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1971,
#    'co2_emissions': 121528.047,
#    'merge_id': 'BEL_1971',
#    'age-standardized_death_rate_per_100k_male': 70.26,
#    'age-standardized_death_rate_per_100k_female': 5.12,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.5},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1972,
#    'co2_emissions': 130834.893,
#    'merge_id': 'BEL_1972',
#    'age-standardized_death_rate_per_100k_male': 72.99,
#    'age-standardized_death_rate_per_100k_female': 5.81,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.600000381469727},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1973,
#    'co2_emissions': 138872.957,
#    'merge_id': 'BEL_1973',
#    'age-standardized_death_rate_per_100k_male': 74.41,
#    'age-standardized_death_rate_per_100k_female': 6.48,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.899999618530273},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1974,
#    'co2_emissions': 135220.625,
#    'merge_id': 'BEL_1974',
#    'age-standardized_death_rate_per_100k_male': 73.74,
#    'age-standardized_death_rate_per_100k_female': 6.07,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.800000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1975,
#    'co2_emissions': 122100.099,
#    'merge_id': 'BEL_1975',
#    'age-standardized_death_rate_per_100k_male': 76.01,
#    'age-standardized_death_rate_per_100k_female': 6.52,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.300000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1976,
#    'co2_emissions': 130009.818,
#    'merge_id': 'BEL_1976',
#    'age-standardized_death_rate_per_100k_male': 78.4,
#    'age-standardized_death_rate_per_100k_female': 6.39,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.199999809265137},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1977,
#    'co2_emissions': 126570.172,
#    'merge_id': 'BEL_1977',
#    'age-standardized_death_rate_per_100k_male': 84.92,
#    'age-standardized_death_rate_per_100k_female': 6.79,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.900000095367432},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1978,
#    'co2_emissions': 135855.016,
#    'merge_id': 'BEL_1978',
#    'age-standardized_death_rate_per_100k_male': 87.11,
#    'age-standardized_death_rate_per_100k_female': 6.45,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1979,
#    'co2_emissions': 140233.414,
#    'merge_id': 'BEL_1979',
#    'age-standardized_death_rate_per_100k_male': 86.52,
#    'age-standardized_death_rate_per_100k_female': 6.61,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1980,
#    'co2_emissions': 135301.299,
#    'merge_id': 'BEL_1980',
#    'age-standardized_death_rate_per_100k_male': 88.33,
#    'age-standardized_death_rate_per_100k_female': 6.93,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1981,
#    'co2_emissions': 124021.607,
#    'merge_id': 'BEL_1981',
#    'age-standardized_death_rate_per_100k_male': 89.28,
#    'age-standardized_death_rate_per_100k_female': 7.59,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.300000190734863},
#   {'country_code': 'BEL',
#    'country_name': 'Belgium',
#    'year': 1982,
#    'co2_emissions': 117553.019,
#    'merge_id': 'BEL_1982',
#    'age-standardized_death_rate_per_100k_male': 87.24,
#    'age-standardized_death_rate_per_100k_female': 7.14,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.100000381469727},
# ...
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1977,
#    'co2_emissions': 356175.71,
#    'merge_id': 'ITA_1977',
#    'age-standardized_death_rate_per_100k_male': 52.27,
#    'age-standardized_death_rate_per_100k_female': 6.5,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1978,
#    'co2_emissions': 373234.594,
#    'merge_id': 'ITA_1978',
#    'age-standardized_death_rate_per_100k_male': 54.43,
#    'age-standardized_death_rate_per_100k_female': 6.29,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1979,
#    'co2_emissions': 387466.221,
#    'merge_id': 'ITA_1979',
#    'age-standardized_death_rate_per_100k_male': 56.72,
#    'age-standardized_death_rate_per_100k_female': 6.63,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1980,
#    'co2_emissions': 388969.691,
#    'merge_id': 'ITA_1980',
#    'age-standardized_death_rate_per_100k_male': 59.24,
#    'age-standardized_death_rate_per_100k_female': 6.71,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1981,
#    'co2_emissions': 378020.029,
#    'merge_id': 'ITA_1981',
#    'age-standardized_death_rate_per_100k_male': 58.54,
#    'age-standardized_death_rate_per_100k_female': 6.87,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1982,
#    'co2_emissions': 369681.271,
#    'merge_id': 'ITA_1982',
#    'age-standardized_death_rate_per_100k_male': 62.04,
#    'age-standardized_death_rate_per_100k_female': 7.06,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.199999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1983,
#    'co2_emissions': 361364.515,
#    'merge_id': 'ITA_1983',
#    'age-standardized_death_rate_per_100k_male': 63.38,
#    'age-standardized_death_rate_per_100k_female': 7.36,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.199999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1984,
#    'co2_emissions': 367649.753,
#    'merge_id': 'ITA_1984',
#    'age-standardized_death_rate_per_100k_male': 63.5,
#    'age-standardized_death_rate_per_100k_female': 7.53,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.300000190734863},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1985,
#    'co2_emissions': 372134.494,
#    'merge_id': 'ITA_1985',
#    'age-standardized_death_rate_per_100k_male': 64.89,
#    'age-standardized_death_rate_per_100k_female': 7.68,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.300000190734863},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1986,
#    'co2_emissions': 366454.311,
#    'merge_id': 'ITA_1986',
#    'age-standardized_death_rate_per_100k_male': 63.59,
#    'age-standardized_death_rate_per_100k_female': 8.11,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.199999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1987,
#    'co2_emissions': 383670.876,
#    'merge_id': 'ITA_1987',
#    'age-standardized_death_rate_per_100k_male': 66.16,
#    'age-standardized_death_rate_per_100k_female': 8.04,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1988,
#    'co2_emissions': 389780.098,
#    'merge_id': 'ITA_1988',
#    'age-standardized_death_rate_per_100k_male': 66.36,
#    'age-standardized_death_rate_per_100k_female': 8.23,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1989,
#    'co2_emissions': 408907.17,
#    'merge_id': 'ITA_1989',
#    'age-standardized_death_rate_per_100k_male': 64.94,
#    'age-standardized_death_rate_per_100k_female': 8.34,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1990,
#    'co2_emissions': 405260.0,
#    'merge_id': 'ITA_1990',
#    'age-standardized_death_rate_per_100k_male': 63.72,
#    'age-standardized_death_rate_per_100k_female': 8.33,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.199999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1991,
#    'co2_emissions': 404070.0,
#    'merge_id': 'ITA_1991',
#    'age-standardized_death_rate_per_100k_male': 63.48,
#    'age-standardized_death_rate_per_100k_female': 8.34,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1992,
#    'co2_emissions': 402270.0,
#    'merge_id': 'ITA_1992',
#    'age-standardized_death_rate_per_100k_male': 63.22,
#    'age-standardized_death_rate_per_100k_female': 9.04,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1993,
#    'co2_emissions': 396930.0,
#    'merge_id': 'ITA_1993',
#    'age-standardized_death_rate_per_100k_male': 62.41,
#    'age-standardized_death_rate_per_100k_female': 8.84,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1994,
#    'co2_emissions': 392290.0,
#    'merge_id': 'ITA_1994',
#    'age-standardized_death_rate_per_100k_male': 61.3,
#    'age-standardized_death_rate_per_100k_female': 8.89,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1995,
#    'co2_emissions': 416420.0,
#    'merge_id': 'ITA_1995',
#    'age-standardized_death_rate_per_100k_male': 59.68,
#    'age-standardized_death_rate_per_100k_female': 9.08,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1996,
#    'co2_emissions': 412150.0,
#    'merge_id': 'ITA_1996',
#    'age-standardized_death_rate_per_100k_male': 58.72,
#    'age-standardized_death_rate_per_100k_female': 9.25,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1997,
#    'co2_emissions': 415520.0,
#    'merge_id': 'ITA_1997',
#    'age-standardized_death_rate_per_100k_male': 57.62,
#    'age-standardized_death_rate_per_100k_female': 9.07,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1998,
#    'co2_emissions': 426370.0,
#    'merge_id': 'ITA_1998',
#    'age-standardized_death_rate_per_100k_male': 56.91,
#    'age-standardized_death_rate_per_100k_female': 9.26,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 1999,
#    'co2_emissions': 433010.0,
#    'merge_id': 'ITA_1999',
#    'age-standardized_death_rate_per_100k_male': 55.93,
#    'age-standardized_death_rate_per_100k_female': 9.2,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.400000095367432},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2000,
#    'co2_emissions': 436300.0,
#    'merge_id': 'ITA_2000',
#    'age-standardized_death_rate_per_100k_male': 54.03,
#    'age-standardized_death_rate_per_100k_female': 9.71,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2001,
#    'co2_emissions': 436570.0,
#    'merge_id': 'ITA_2001',
#    'age-standardized_death_rate_per_100k_male': 53.47,
#    'age-standardized_death_rate_per_100k_female': 9.81,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2002,
#    'co2_emissions': 443470.001220703,
#    'merge_id': 'ITA_2002',
#    'age-standardized_death_rate_per_100k_male': 51.94,
#    'age-standardized_death_rate_per_100k_female': 10.17,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.800000190734863},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2003,
#    'co2_emissions': 462200.012207031,
#    'merge_id': 'ITA_2003',
#    'age-standardized_death_rate_per_100k_male': 50.7,
#    'age-standardized_death_rate_per_100k_female': 9.83,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2004,
#    'co2_emissions': 472399.993896484,
#    'merge_id': 'ITA_2004',
#    'age-standardized_death_rate_per_100k_male': 48.76,
#    'age-standardized_death_rate_per_100k_female': 10.16,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.400000095367432},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2005,
#    'co2_emissions': 473829.986572266,
#    'merge_id': 'ITA_2005',
#    'age-standardized_death_rate_per_100k_male': 47.74,
#    'age-standardized_death_rate_per_100k_female': 10.14,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2006,
#    'co2_emissions': 466649.993896484,
#    'merge_id': 'ITA_2006',
#    'age-standardized_death_rate_per_100k_male': 46.7,
#    'age-standardized_death_rate_per_100k_female': 10.42,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2007,
#    'co2_emissions': 459369.995117188,
#    'merge_id': 'ITA_2007',
#    'age-standardized_death_rate_per_100k_male': 45.54,
#    'age-standardized_death_rate_per_100k_female': 10.77,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2008,
#    'co2_emissions': 444980.010986328,
#    'merge_id': 'ITA_2008',
#    'age-standardized_death_rate_per_100k_male': 44.28,
#    'age-standardized_death_rate_per_100k_female': 10.87,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.0},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2009,
#    'co2_emissions': 397059.997558594,
#    'merge_id': 'ITA_2009',
#    'age-standardized_death_rate_per_100k_male': 43.36,
#    'age-standardized_death_rate_per_100k_female': 11.08,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.800000190734863},
#   {'country_code': 'ITA',
#    'country_name': 'Italy',
#    'year': 2010,
#    'co2_emissions': 405269.989013672,
#    'merge_id': 'ITA_2010',
#    'age-standardized_death_rate_per_100k_male': 42.5,
#    'age-standardized_death_rate_per_100k_female': 11.19,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 4.699999809265137},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1960,
#    'co2_emissions': 232781.16,
#    'merge_id': 'JPN_1960',
#    'age-standardized_death_rate_per_100k_male': 10.88,
#    'age-standardized_death_rate_per_100k_female': 3.88,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.099999904632568},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1961,
#    'co2_emissions': 283118.069,
#    'merge_id': 'JPN_1961',
#    'age-standardized_death_rate_per_100k_male': 11.43,
#    'age-standardized_death_rate_per_100k_female': 4.33,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.599999904632568},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1962,
#    'co2_emissions': 293220.654,
#    'merge_id': 'JPN_1962',
#    'age-standardized_death_rate_per_100k_male': 12.31,
#    'age-standardized_death_rate_per_100k_female': 4.53,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.699999809265137},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1963,
#    'co2_emissions': 325222.563,
#    'merge_id': 'JPN_1963',
#    'age-standardized_death_rate_per_100k_male': 13.19,
#    'age-standardized_death_rate_per_100k_female': 4.64,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 5.900000095367432},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1964,
#    'co2_emissions': 359318.329,
#    'merge_id': 'JPN_1964',
#    'age-standardized_death_rate_per_100k_male': 13.85,
#    'age-standardized_death_rate_per_100k_female': 4.82,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.199999809265137},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1965,
#    'co2_emissions': 386919.838,
#    'merge_id': 'JPN_1965',
#    'age-standardized_death_rate_per_100k_male': 14.44,
#    'age-standardized_death_rate_per_100k_female': 5.2,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.400000095367432},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1966,
#    'co2_emissions': 419743.155,
#    'merge_id': 'JPN_1966',
#    'age-standardized_death_rate_per_100k_male': 15.24,
#    'age-standardized_death_rate_per_100k_female': 5.48,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 6.699999809265137},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1967,
#    'co2_emissions': 489881.864,
#    'merge_id': 'JPN_1967',
#    'age-standardized_death_rate_per_100k_male': 16.1,
#    'age-standardized_death_rate_per_100k_female': 5.45,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1968,
#    'co2_emissions': 562565.471,
#    'merge_id': 'JPN_1968',
#    'age-standardized_death_rate_per_100k_male': 16.63,
#    'age-standardized_death_rate_per_100k_female': 5.58,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.0},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1969,
#    'co2_emissions': 653958.112,
#    'merge_id': 'JPN_1969',
#    'age-standardized_death_rate_per_100k_male': 17.65,
#    'age-standardized_death_rate_per_100k_female': 5.89,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.5},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1970,
#    'co2_emissions': 768823.22,
#    'merge_id': 'JPN_1970',
#    'age-standardized_death_rate_per_100k_male': 17.87,
#    'age-standardized_death_rate_per_100k_female': 5.84,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 7.800000190734863},
#   {'country_code': 'JPN',
#    'country_name': 'Japan',
#    'year': 1971,
#    'co2_emissions': 797543.164,
#    'merge_id': 'JPN_1971',
#    'age-standardized_death_rate_per_100k_male': 18.8,
#    'age-standardized_death_rate_per_100k_female': 5.84,
#    'Sales of cigarettes per adult per day (International Smoking Statistics (2017)) ': 8.199999809265137},
#   ...]}
